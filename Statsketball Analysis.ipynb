# %% [markdown]
# # **Statsketball Analysis**

# %%
#import the python scientific suite
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import sklearn
import seaborn as sns
import scipy
import pylab
import statsmodels

from sklearn.cross_validation import *
from sklearn import svm, linear_model
from sklearn import preprocessing, cross_validation, neighbors
from sklearn.metrics import confusion_matrix, roc_curve, auc
from sklearn.ensemble import ExtraTreesClassifier, ExtraTreesRegressor
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn import tree

from textblob import TextBlob

import statsmodels.api as sm
from collections import defaultdict


# This is importing a "future" python version 3 print function.
from __future__ import print_function
from __future__ import division

#plot figures inline in Jupyter notebooks
# %matplotlib inline 

#use seaborn for plotting
sns.set()
sns.set_context('paper', font_scale = 1.5)
sns.set_style('ticks')
pylab.rcParams.update({'figure.autolayout': True})

# %%
def train_and_evaluate(clf, X_train, y_train, verbose = False):
        
    clf.fit(X_train, y_train) #fit the model

    #create a k-fold cross validation iterator of k = 5 folds

    cv = KFold(X_train.shape[0], 10, shuffle = True)
    scores = cross_val_score(clf, X_train, y_train, cv = cv)

    if verbose == True: #if we want to print status
        print("Coefficient of determination on training set:", clf.score(X_train, y_train))
        print("Average coefficient of determination using 10-fold crossvalidation:", np.mean(scores))
    
    return clf.score(X_train, y_train), np.mean(scores)

# %% [markdown]
# # Reading in Data files

# %%
file_dir = '~/Statsketball/Statsketball-Tournament/Master_Data/'

num = np.arange(2002,2017)
f = dict()
for n in num:
    f.update({str(n): str(n)+'_master.csv'})

d = defaultdict()

for fi in f:
    d[fi] = pd.read_csv(file_dir + f[fi])
    d[fi] = d[fi].drop(['Unnamed: 0'], 1)

# %%
print (f.keys())
# Out:
# dict_keys(['2013', '2010', '2003', '2011', '2009', '2005', '2002', '2014', '2007', '2008', '2012', '2016', '2004', '2006', '2015'])

# %%
d['2013'].head()
# Out:
#                  team_X                    team_Y  AdjEM_x-y  AdjO_x-y  \
# 0               Indiana             James Madison      30.19      20.6
# 1  North Carolina State                    Temple        NaN       NaN
# 2                  UNLV  University of California        NaN       NaN
# 3              Syracuse                   Montana      22.60       8.2
# 4                Butler                  Bucknell       2.67       3.3
#
#    AdjD_x-y  AdjT_x-y  luck_x-y  W_x-y  L_x-y  W_L_ratio_x-y  SRS_x-y  \
# 0      -9.5       2.6    -0.084    8.0   -8.0          0.223    26.63
# 1       NaN       NaN       NaN    0.0    1.0         -0.020     4.80
# 2       NaN       NaN       NaN    NaN    NaN            NaN      NaN
# 3     -14.3       0.3    -0.179    5.0    3.0         -0.031    21.41
# 4       0.7       1.7     0.102   -1.0    3.0         -0.074     4.04
#
#    SOS_x-y  TM_pt_x-y  OPPO_pt_x-y  PT_Ratio_x-y  True_S_x-y  seed_x-y  \
# 0    10.66      485.0        -90.0      0.257502       0.076       -15
# 1     1.97      252.0        149.0      0.038045       0.042        -1
# 2      NaN        NaN          NaN           NaN         NaN        -7
# 3    12.78      578.0        251.0      0.132081      -0.053        -9
# 4     8.04      218.0        333.0     -0.072935       0.008        -5
#
#    point_diff_x-y result
# 0              21      X
# 1              -4      Y
# 2              -3      Y
# 3              47      X
# 4              12      X

# %% [markdown]
# # Regression/Random Forset/LASSO Predictions

# %%
d['master'] = pd.DataFrame()

for n in num:
    d['master'] = d['master'].append(d[str(n)])

d['master'] = d['master'].dropna()
d['master'].index = range(len(d['master']))

# %%
list(d['master'])
# Out:
# ['team_X',
#  'team_Y',
#  'AdjEM_x-y',
#  'AdjO_x-y',
#  'AdjD_x-y',
#  'AdjT_x-y',
#  'luck_x-y',
#  'W_x-y',
#  'L_x-y',
#  'W_L_ratio_x-y',
#  'SRS_x-y',
#  'SOS_x-y',
#  'TM_pt_x-y',
#  'OPPO_pt_x-y',
#  'PT_Ratio_x-y',
#  'True_S_x-y',
#  'seed_x-y',
#  'point_diff_x-y',
#  'result']

# %%
print ("Number of data points: ", len(d['master']))
# Out:
# Number of data points:  222

# %% [markdown]
# ## Regression Models: Using Point Difference as Response Variable

# %%
# One feature prediciton: on "W_L_ratio"
c_response = d['master'][['point_diff_x-y']]
c_features = d['master'][['AdjEM_x-y']]

# %%
d['master'].isnull().sum().sum()
# Out:
# 0

# %%
models = {'LASSO': linear_model.Lasso(alpha = 10E-6),\
         'LINEAR': linear_model.LinearRegression(),\
         'RF': RandomForestRegressor()}

#now, split the data in to training and testing sets using the sklearn function train_test_split

std_errors = defaultdict(list)

for sim in range(100):
    X_train, X_test, y_train, y_test = train_test_split(c_features, c_response, test_size = 0.50)
    print(X_train.columns)
    for model in models: #for every model in our model dictionary
        print (model, ': ')
        train_and_evaluate(models[model], X_train, np.ravel(y_train), verbose = True) #train the model on the data
        print('\n')
        
    #std_errors['W_L_ratio'].append(np.std(np.array(models['RF'].predict(X_test)) - y_test['point_diff']))
# Out:
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.84551505585
# Average coefficient of determination using 5-fold crossvalidation: -0.182984197634
#
#
# LASSO :
# Coefficient of determination on training set: 0.435309553766
# Average coefficient of determination using 5-fold crossvalidation: 0.277600997966
#
#
# LINEAR :
# Coefficient of determination on training set: 0.435309553766
# Average coefficient of determination using 5-fold crossvalidation: 0.392700575457
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.792460531586
# Average coefficient of determination using 5-fold crossvalidation: -0.222256199159
#
#
# LASSO :
# Coefficient of determination on training set: 0.388449899328
# Average coefficient of determination using 5-fold crossvalidation: 0.344769916164
#
#
# LINEAR :
# Coefficient of determination on training set: 0.388449899328
# Average coefficient of determination using 5-fold crossvalidation: 0.197727871949
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.841476732762
# Average coefficient of determination using 5-fold crossvalidation: 0.0816340922492
#
#
# LASSO :
# Coefficient of determination on training set: 0.337323591056
# Average coefficient of determination using 5-fold crossvalidation: 0.208276511667
#
#
# LINEAR :
# Coefficient of determination on training set: 0.337323591056
# Average coefficient of determination using 5-fold crossvalidation: 0.260195033479
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.848457074483
# Average coefficient of determination using 5-fold crossvalidation: 0.00601335430431
#
#
# LASSO :
# Coefficient of determination on training set: 0.366169861016
# Average coefficient of determination using 5-fold crossvalidation: 0.274400839059
#
#
# LINEAR :
# Coefficient of determination on training set: 0.366169861016
# Average coefficient of determination using 5-fold crossvalidation: 0.25885236348
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.878718225472
# Average coefficient of determination using 5-fold crossvalidation: 0.205011939075
#
#
# LASSO :
# Coefficient of determination on training set: 0.449847274525
# Average coefficient of determination using 5-fold crossvalidation: 0.381136398489
#
#
# LINEAR :
# Coefficient of determination on training set: 0.449847274525
# Average coefficient of determination using 5-fold crossvalidation: 0.388184674591
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.84517515439
# Average coefficient of determination using 5-fold crossvalidation: 0.0681575753813
#
#
# LASSO :
# Coefficient of determination on training set: 0.401564321618
# Average coefficient of determination using 5-fold crossvalidation: 0.382708451507
#
#
# LINEAR :
# Coefficient of determination on training set: 0.401564321618
# Average coefficient of determination using 5-fold crossvalidation: 0.360021014592
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.868432956508
# Average coefficient of determination using 5-fold crossvalidation: 0.0762162813313
#
#
# LASSO :
# Coefficient of determination on training set: 0.465934407202
# Average coefficient of determination using 5-fold crossvalidation: 0.386157357351
#
#
# LINEAR :
# Coefficient of determination on training set: 0.465934407203
# Average coefficient of determination using 5-fold crossvalidation: 0.450534283113
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.829235694268
# Average coefficient of determination using 5-fold crossvalidation: 0.109233683176
#
#
# LASSO :
# Coefficient of determination on training set: 0.488784498751
# Average coefficient of determination using 5-fold crossvalidation: 0.452512032914
#
#
# LINEAR :
# Coefficient of determination on training set: 0.488784498751
# Average coefficient of determination using 5-fold crossvalidation: 0.467215829629
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.827563139059
# Average coefficient of determination using 5-fold crossvalidation: -0.179311634658
#
#
# LASSO :
# Coefficient of determination on training set: 0.393761556262
# Average coefficient of determination using 5-fold crossvalidation: 0.32978520133
#
#
# LINEAR :
# Coefficient of determination on training set: 0.393761556262
# Average coefficient of determination using 5-fold crossvalidation: 0.336544922116
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.838357338424
# Average coefficient of determination using 5-fold crossvalidation: 0.140914929641
#
#
# LASSO :
# Coefficient of determination on training set: 0.364046787881
# Average coefficient of determination using 5-fold crossvalidation: 0.348166913419
#
#
# LINEAR :
# Coefficient of determination on training set: 0.364046787881
# Average coefficient of determination using 5-fold crossvalidation: 0.295292439331
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.785257615384
# Average coefficient of determination using 5-fold crossvalidation: 0.173027146288
#
#
# LASSO :
# Coefficient of determination on training set: 0.344947016125
# Average coefficient of determination using 5-fold crossvalidation: 0.285906019548
#
#
# LINEAR :
# Coefficient of determination on training set: 0.344947016125
# Average coefficient of determination using 5-fold crossvalidation: 0.250202706054
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.82616867758
# Average coefficient of determination using 5-fold crossvalidation: -0.133910319961
#
#
# LASSO :
# Coefficient of determination on training set: 0.363656533675
# Average coefficient of determination using 5-fold crossvalidation: 0.224476996277
#
#
# LINEAR :
# Coefficient of determination on training set: 0.363656533675
# Average coefficient of determination using 5-fold crossvalidation: 0.282207140088
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.811995420353
# Average coefficient of determination using 5-fold crossvalidation: 0.0590092816774
#
#
# LASSO :
# Coefficient of determination on training set: 0.377365451243
# Average coefficient of determination using 5-fold crossvalidation: 0.309246176354
#
#
# LINEAR :
# Coefficient of determination on training set: 0.377365451243
# Average coefficient of determination using 5-fold crossvalidation: 0.311508564268
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.870081041964
# Average coefficient of determination using 5-fold crossvalidation: 0.0528873428586
#
#
# LASSO :
# Coefficient of determination on training set: 0.449160888155
# Average coefficient of determination using 5-fold crossvalidation: 0.400776442646
#
#
# LINEAR :
# Coefficient of determination on training set: 0.449160888155
# Average coefficient of determination using 5-fold crossvalidation: 0.354779924301
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.83488324961
# Average coefficient of determination using 5-fold crossvalidation: 0.0735341786128
#
#
# LASSO :
# Coefficient of determination on training set: 0.453248851829
# Average coefficient of determination using 5-fold crossvalidation: 0.397812964221
#
#
# LINEAR :
# Coefficient of determination on training set: 0.453248851829
# Average coefficient of determination using 5-fold crossvalidation: 0.372309564371
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.853709144574
# Average coefficient of determination using 5-fold crossvalidation: -0.288506701222
#
#
# LASSO :
# Coefficient of determination on training set: 0.374394127815
# Average coefficient of determination using 5-fold crossvalidation: 0.272736156701
#
#
# LINEAR :
# Coefficient of determination on training set: 0.374394127815
# Average coefficient of determination using 5-fold crossvalidation: 0.264249195661
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.862238967831
# Average coefficient of determination using 5-fold crossvalidation: -0.097490974379
#
#
# LASSO :
# Coefficient of determination on training set: 0.441743092056
# Average coefficient of determination using 5-fold crossvalidation: 0.422206221161
#
#
# LINEAR :
# Coefficient of determination on training set: 0.441743092056
# Average coefficient of determination using 5-fold crossvalidation: 0.341334894379
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.746299029432
# Average coefficient of determination using 5-fold crossvalidation: -0.202564479061
#
#
# LASSO :
# Coefficient of determination on training set: 0.33861223967
# Average coefficient of determination using 5-fold crossvalidation: 0.257611114061
#
#
# LINEAR :
# Coefficient of determination on training set: 0.33861223967
# Average coefficient of determination using 5-fold crossvalidation: 0.284249068322
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.795566647462
# Average coefficient of determination using 5-fold crossvalidation: -0.222368358809
#
#
# LASSO :
# Coefficient of determination on training set: 0.365164145302
# Average coefficient of determination using 5-fold crossvalidation: 0.319929843148
#
#
# LINEAR :
# Coefficient of determination on training set: 0.365164145302
# Average coefficient of determination using 5-fold crossvalidation: 0.228641646495
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.84148601403
# Average coefficient of determination using 5-fold crossvalidation: 0.0791746592472
#
#
# LASSO :
# Coefficient of determination on training set: 0.407659048712
# Average coefficient of determination using 5-fold crossvalidation: 0.329461256063
#
#
# LINEAR :
# Coefficient of determination on training set: 0.407659048712
# Average coefficient of determination using 5-fold crossvalidation: 0.270391053974
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.838001503016
# Average coefficient of determination using 5-fold crossvalidation: 0.0808007293515
#
#
# LASSO :
# Coefficient of determination on training set: 0.386216577358
# Average coefficient of determination using 5-fold crossvalidation: 0.345513916699
#
#
# LINEAR :
# Coefficient of determination on training set: 0.386216577358
# Average coefficient of determination using 5-fold crossvalidation: 0.285948369416
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.823070793142
# Average coefficient of determination using 5-fold crossvalidation: -0.273557210002
#
#
# LASSO :
# Coefficient of determination on training set: 0.395015663117
# Average coefficient of determination using 5-fold crossvalidation: 0.203877242184
#
#
# LINEAR :
# Coefficient of determination on training set: 0.395015663117
# Average coefficient of determination using 5-fold crossvalidation: 0.30926568334
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.778634731083
# Average coefficient of determination using 5-fold crossvalidation: -0.157449098358
#
#
# LASSO :
# Coefficient of determination on training set: 0.270532859184
# Average coefficient of determination using 5-fold crossvalidation: 0.179380735077
#
#
# LINEAR :
# Coefficient of determination on training set: 0.270532859184
# Average coefficient of determination using 5-fold crossvalidation: 0.216109194436
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.812490323362
# Average coefficient of determination using 5-fold crossvalidation: -0.343870254393
#
#
# LASSO :
# Coefficient of determination on training set: 0.43909740655
# Average coefficient of determination using 5-fold crossvalidation: 0.347825961937
#
#
# LINEAR :
# Coefficient of determination on training set: 0.43909740655
# Average coefficient of determination using 5-fold crossvalidation: 0.391566553957
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.861734709874
# Average coefficient of determination using 5-fold crossvalidation: -0.00981661833658
#
#
# LASSO :
# Coefficient of determination on training set: 0.453168009633
# Average coefficient of determination using 5-fold crossvalidation: 0.362862587538
#
#
# LINEAR :
# Coefficient of determination on training set: 0.453168009633
# Average coefficient of determination using 5-fold crossvalidation: 0.396913238409
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.847295768929
# Average coefficient of determination using 5-fold crossvalidation: 0.0743938652789
#
#
# LASSO :
# Coefficient of determination on training set: 0.468093223589
# Average coefficient of determination using 5-fold crossvalidation: 0.341460674862
#
#
# LINEAR :
# Coefficient of determination on training set: 0.468093223589
# Average coefficient of determination using 5-fold crossvalidation: 0.386441647357
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.833180615409
# Average coefficient of determination using 5-fold crossvalidation: 0.123892954895
#
#
# LASSO :
# Coefficient of determination on training set: 0.45363162232
# Average coefficient of determination using 5-fold crossvalidation: 0.367451024585
#
#
# LINEAR :
# Coefficient of determination on training set: 0.45363162232
# Average coefficient of determination using 5-fold crossvalidation: 0.392543830138
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.797597073576
# Average coefficient of determination using 5-fold crossvalidation: -0.0543660346176
#
#
# LASSO :
# Coefficient of determination on training set: 0.413063375489
# Average coefficient of determination using 5-fold crossvalidation: 0.321778736857
#
#
# LINEAR :
# Coefficient of determination on training set: 0.413063375489
# Average coefficient of determination using 5-fold crossvalidation: 0.403767643855
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.799828682159
# Average coefficient of determination using 5-fold crossvalidation: 0.0350099712419
#
#
# LASSO :
# Coefficient of determination on training set: 0.428098939759
# Average coefficient of determination using 5-fold crossvalidation: 0.290771536304
#
#
# LINEAR :
# Coefficient of determination on training set: 0.428098939759
# Average coefficient of determination using 5-fold crossvalidation: 0.410933171247
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.828123034067
# Average coefficient of determination using 5-fold crossvalidation: -0.0287541557718
#
#
# LASSO :
# Coefficient of determination on training set: 0.404238343353
# Average coefficient of determination using 5-fold crossvalidation: 0.371910643874
#
#
# LINEAR :
# Coefficient of determination on training set: 0.404238343353
# Average coefficient of determination using 5-fold crossvalidation: 0.367719034157
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.831855154809
# Average coefficient of determination using 5-fold crossvalidation: -0.137560934369
#
#
# LASSO :
# Coefficient of determination on training set: 0.400998407729
# Average coefficient of determination using 5-fold crossvalidation: 0.352570160605
#
#
# LINEAR :
# Coefficient of determination on training set: 0.40099840773
# Average coefficient of determination using 5-fold crossvalidation: 0.296885783371
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.802675710169
# Average coefficient of determination using 5-fold crossvalidation: -0.132146746198
#
#
# LASSO :
# Coefficient of determination on training set: 0.329924042839
# Average coefficient of determination using 5-fold crossvalidation: 0.257090988484
#
#
# LINEAR :
# Coefficient of determination on training set: 0.329924042839
# Average coefficient of determination using 5-fold crossvalidation: 0.243551500949
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.828519115344
# Average coefficient of determination using 5-fold crossvalidation: 0.0515891770079
#
#
# LASSO :
# Coefficient of determination on training set: 0.345562066066
# Average coefficient of determination using 5-fold crossvalidation: 0.113060328292
#
#
# LINEAR :
# Coefficient of determination on training set: 0.345562066066
# Average coefficient of determination using 5-fold crossvalidation: 0.227090347465
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.786440631963
# Average coefficient of determination using 5-fold crossvalidation: -0.2039493492
#
#
# LASSO :
# Coefficient of determination on training set: 0.387190706394
# Average coefficient of determination using 5-fold crossvalidation: 0.3148730019
#
#
# LINEAR :
# Coefficient of determination on training set: 0.387190706394
# Average coefficient of determination using 5-fold crossvalidation: 0.312961545095
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.796291920326
# Average coefficient of determination using 5-fold crossvalidation: -0.446605496061
#
#
# LASSO :
# Coefficient of determination on training set: 0.300240202843
# Average coefficient of determination using 5-fold crossvalidation: 0.245038477716
#
#
# LINEAR :
# Coefficient of determination on training set: 0.300240202843
# Average coefficient of determination using 5-fold crossvalidation: 0.269929883828
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.813237078751
# Average coefficient of determination using 5-fold crossvalidation: -0.0929782073247
#
#
# LASSO :
# Coefficient of determination on training set: 0.348830142785
# Average coefficient of determination using 5-fold crossvalidation: 0.269791446201
#
#
# LINEAR :
# Coefficient of determination on training set: 0.348830142785
# Average coefficient of determination using 5-fold crossvalidation: 0.289767308184
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.802766760799
# Average coefficient of determination using 5-fold crossvalidation: -0.195278788823
#
#
# LASSO :
# Coefficient of determination on training set: 0.423517480238
# Average coefficient of determination using 5-fold crossvalidation: 0.319280672991
#
#
# LINEAR :
# Coefficient of determination on training set: 0.423517480238
# Average coefficient of determination using 5-fold crossvalidation: 0.155003067645
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.808911591142
# Average coefficient of determination using 5-fold crossvalidation: -0.175277029294
#
#
# LASSO :
# Coefficient of determination on training set: 0.409758117348
# Average coefficient of determination using 5-fold crossvalidation: 0.289935645457
#
#
# LINEAR :
# Coefficient of determination on training set: 0.409758117348
# Average coefficient of determination using 5-fold crossvalidation: 0.335023759184
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.854899411053
# Average coefficient of determination using 5-fold crossvalidation: 0.0899072681136
#
#
# LASSO :
# Coefficient of determination on training set: 0.427987122829
# Average coefficient of determination using 5-fold crossvalidation: 0.352561947301
#
#
# LINEAR :
# Coefficient of determination on training set: 0.427987122829
# Average coefficient of determination using 5-fold crossvalidation: 0.397299905282
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.856586218839
# Average coefficient of determination using 5-fold crossvalidation: 0.113503372931
#
#
# LASSO :
# Coefficient of determination on training set: 0.441061000539
# Average coefficient of determination using 5-fold crossvalidation: 0.304227120032
#
#
# LINEAR :
# Coefficient of determination on training set: 0.441061000539
# Average coefficient of determination using 5-fold crossvalidation: 0.425432123552
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.797983926389
# Average coefficient of determination using 5-fold crossvalidation: -0.0847156880212
#
#
# LASSO :
# Coefficient of determination on training set: 0.432625297653
# Average coefficient of determination using 5-fold crossvalidation: 0.242889945476
#
#
# LINEAR :
# Coefficient of determination on training set: 0.432625297653
# Average coefficient of determination using 5-fold crossvalidation: 0.358461586597
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.861329059983
# Average coefficient of determination using 5-fold crossvalidation: 0.127890575033
#
#
# LASSO :
# Coefficient of determination on training set: 0.384769622235
# Average coefficient of determination using 5-fold crossvalidation: 0.296036054767
#
#
# LINEAR :
# Coefficient of determination on training set: 0.384769622235
# Average coefficient of determination using 5-fold crossvalidation: 0.271477137071
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.851297692556
# Average coefficient of determination using 5-fold crossvalidation: -0.0313012844589
#
#
# LASSO :
# Coefficient of determination on training set: 0.458001150443
# Average coefficient of determination using 5-fold crossvalidation: 0.392154967281
#
#
# LINEAR :
# Coefficient of determination on training set: 0.458001150443
# Average coefficient of determination using 5-fold crossvalidation: 0.3257766675
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.857444302708
# Average coefficient of determination using 5-fold crossvalidation: 0.0773714531615
#
#
# LASSO :
# Coefficient of determination on training set: 0.442800168843
# Average coefficient of determination using 5-fold crossvalidation: 0.405552959408
#
#
# LINEAR :
# Coefficient of determination on training set: 0.442800168843
# Average coefficient of determination using 5-fold crossvalidation: 0.252493073673
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.86347807473
# Average coefficient of determination using 5-fold crossvalidation: 0.0401935139373
#
#
# LASSO :
# Coefficient of determination on training set: 0.377581966555
# Average coefficient of determination using 5-fold crossvalidation: 0.234595495398
#
#
# LINEAR :
# Coefficient of determination on training set: 0.377581966555
# Average coefficient of determination using 5-fold crossvalidation: 0.36347876341
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.736853271314
# Average coefficient of determination using 5-fold crossvalidation: -0.36894678493
#
#
# LASSO :
# Coefficient of determination on training set: 0.32938833888
# Average coefficient of determination using 5-fold crossvalidation: 0.225965224912
#
#
# LINEAR :
# Coefficient of determination on training set: 0.32938833888
# Average coefficient of determination using 5-fold crossvalidation: 0.192706075545
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.845903725989
# Average coefficient of determination using 5-fold crossvalidation: 0.0859770062707
#
#
# LASSO :
# Coefficient of determination on training set: 0.410335626943
# Average coefficient of determination using 5-fold crossvalidation: 0.266311037413
#
#
# LINEAR :
# Coefficient of determination on training set: 0.410335626943
# Average coefficient of determination using 5-fold crossvalidation: 0.289642068708
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.83554622092
# Average coefficient of determination using 5-fold crossvalidation: -0.00501706610443
#
#
# LASSO :
# Coefficient of determination on training set: 0.408804249758
# Average coefficient of determination using 5-fold crossvalidation: 0.268582223845
#
#
# LINEAR :
# Coefficient of determination on training set: 0.408804249758
# Average coefficient of determination using 5-fold crossvalidation: 0.275378423793
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.820138570467
# Average coefficient of determination using 5-fold crossvalidation: -0.132390712642
#
#
# LASSO :
# Coefficient of determination on training set: 0.341340100511
# Average coefficient of determination using 5-fold crossvalidation: 0.251523930764
#
#
# LINEAR :
# Coefficient of determination on training set: 0.341340100511
# Average coefficient of determination using 5-fold crossvalidation: 0.220324189443
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.840098749716
# Average coefficient of determination using 5-fold crossvalidation: 0.00867417998152
#
#
# LASSO :
# Coefficient of determination on training set: 0.393321608511
# Average coefficient of determination using 5-fold crossvalidation: 0.349422717229
#
#
# LINEAR :
# Coefficient of determination on training set: 0.393321608511
# Average coefficient of determination using 5-fold crossvalidation: 0.374897108183
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.842440406184
# Average coefficient of determination using 5-fold crossvalidation: -0.0177458337535
#
#
# LASSO :
# Coefficient of determination on training set: 0.39347001865
# Average coefficient of determination using 5-fold crossvalidation: 0.337481575587
#
#
# LINEAR :
# Coefficient of determination on training set: 0.39347001865
# Average coefficient of determination using 5-fold crossvalidation: 0.270884951042
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.842749062588
# Average coefficient of determination using 5-fold crossvalidation: -0.176620010879
#
#
# LASSO :
# Coefficient of determination on training set: 0.428749031898
# Average coefficient of determination using 5-fold crossvalidation: 0.395481579566
#
#
# LINEAR :
# Coefficient of determination on training set: 0.428749031898
# Average coefficient of determination using 5-fold crossvalidation: 0.381681506299
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.845100722859
# Average coefficient of determination using 5-fold crossvalidation: -0.0404288871841
#
#
# LASSO :
# Coefficient of determination on training set: 0.453619408058
# Average coefficient of determination using 5-fold crossvalidation: 0.412349861424
#
#
# LINEAR :
# Coefficient of determination on training set: 0.453619408058
# Average coefficient of determination using 5-fold crossvalidation: 0.357772728546
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.866808991209
# Average coefficient of determination using 5-fold crossvalidation: 0.00823710426145
#
#
# LASSO :
# Coefficient of determination on training set: 0.407509743402
# Average coefficient of determination using 5-fold crossvalidation: 0.325211534812
#
#
# LINEAR :
# Coefficient of determination on training set: 0.407509743402
# Average coefficient of determination using 5-fold crossvalidation: 0.308041470489
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.848465248117
# Average coefficient of determination using 5-fold crossvalidation: -0.178342498039
#
#
# LASSO :
# Coefficient of determination on training set: 0.360443027546
# Average coefficient of determination using 5-fold crossvalidation: 0.217971452921
#
#
# LINEAR :
# Coefficient of determination on training set: 0.360443027546
# Average coefficient of determination using 5-fold crossvalidation: 0.293324111705
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.800864858896
# Average coefficient of determination using 5-fold crossvalidation: -0.0803918088992
#
#
# LASSO :
# Coefficient of determination on training set: 0.306639714273
# Average coefficient of determination using 5-fold crossvalidation: 0.239058027843
#
#
# LINEAR :
# Coefficient of determination on training set: 0.306639714273
# Average coefficient of determination using 5-fold crossvalidation: 0.299269956969
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.812717378928
# Average coefficient of determination using 5-fold crossvalidation: -0.0225981876241
#
#
# LASSO :
# Coefficient of determination on training set: 0.375161384938
# Average coefficient of determination using 5-fold crossvalidation: 0.206247856661
#
#
# LINEAR :
# Coefficient of determination on training set: 0.375161384938
# Average coefficient of determination using 5-fold crossvalidation: 0.20372580436
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.843553041209
# Average coefficient of determination using 5-fold crossvalidation: 0.107785743274
#
#
# LASSO :
# Coefficient of determination on training set: 0.455418031844
# Average coefficient of determination using 5-fold crossvalidation: 0.428217277072
#
#
# LINEAR :
# Coefficient of determination on training set: 0.455418031844
# Average coefficient of determination using 5-fold crossvalidation: 0.414041135691
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.77094418744
# Average coefficient of determination using 5-fold crossvalidation: -0.362359398079
#
#
# LASSO :
# Coefficient of determination on training set: 0.327252478883
# Average coefficient of determination using 5-fold crossvalidation: 0.300170167266
#
#
# LINEAR :
# Coefficient of determination on training set: 0.327252478883
# Average coefficient of determination using 5-fold crossvalidation: 0.222774177832
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.830216538956
# Average coefficient of determination using 5-fold crossvalidation: 0.0196294213427
#
#
# LASSO :
# Coefficient of determination on training set: 0.392518072968
# Average coefficient of determination using 5-fold crossvalidation: 0.131366535226
#
#
# LINEAR :
# Coefficient of determination on training set: 0.392518072968
# Average coefficient of determination using 5-fold crossvalidation: 0.279420035033
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.806633509008
# Average coefficient of determination using 5-fold crossvalidation: 0.0208286424439
#
#
# LASSO :
# Coefficient of determination on training set: 0.390894417154
# Average coefficient of determination using 5-fold crossvalidation: 0.375584086346
#
#
# LINEAR :
# Coefficient of determination on training set: 0.390894417154
# Average coefficient of determination using 5-fold crossvalidation: 0.366394579713
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.808539266634
# Average coefficient of determination using 5-fold crossvalidation: 0.0889784653567
#
#
# LASSO :
# Coefficient of determination on training set: 0.44067853299
# Average coefficient of determination using 5-fold crossvalidation: 0.404619330882
#
#
# LINEAR :
# Coefficient of determination on training set: 0.44067853299
# Average coefficient of determination using 5-fold crossvalidation: 0.415952450721
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.829328165188
# Average coefficient of determination using 5-fold crossvalidation: -0.104773419217
#
#
# LASSO :
# Coefficient of determination on training set: 0.39246154343
# Average coefficient of determination using 5-fold crossvalidation: 0.381395087673
#
#
# LINEAR :
# Coefficient of determination on training set: 0.39246154343
# Average coefficient of determination using 5-fold crossvalidation: 0.271329506024
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.845668944461
# Average coefficient of determination using 5-fold crossvalidation: 0.0529422623914
#
#
# LASSO :
# Coefficient of determination on training set: 0.362396679635
# Average coefficient of determination using 5-fold crossvalidation: 0.283603272386
#
#
# LINEAR :
# Coefficient of determination on training set: 0.362396679635
# Average coefficient of determination using 5-fold crossvalidation: 0.33395772704
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.863081576572
# Average coefficient of determination using 5-fold crossvalidation: 0.037389327159
#
#
# LASSO :
# Coefficient of determination on training set: 0.469219645308
# Average coefficient of determination using 5-fold crossvalidation: 0.443186802799
#
#
# LINEAR :
# Coefficient of determination on training set: 0.469219645308
# Average coefficient of determination using 5-fold crossvalidation: 0.356226313333
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.874380968206
# Average coefficient of determination using 5-fold crossvalidation: 0.0631491151375
#
#
# LASSO :
# Coefficient of determination on training set: 0.371957077869
# Average coefficient of determination using 5-fold crossvalidation: 0.314680426327
#
#
# LINEAR :
# Coefficient of determination on training set: 0.371957077869
# Average coefficient of determination using 5-fold crossvalidation: 0.358694188624
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.834465312036
# Average coefficient of determination using 5-fold crossvalidation: 0.144377697077
#
#
# LASSO :
# Coefficient of determination on training set: 0.360868060252
# Average coefficient of determination using 5-fold crossvalidation: 0.274960347824
#
#
# LINEAR :
# Coefficient of determination on training set: 0.360868060252
# Average coefficient of determination using 5-fold crossvalidation: 0.318073603823
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.822801118805
# Average coefficient of determination using 5-fold crossvalidation: 0.0105991680865
#
#
# LASSO :
# Coefficient of determination on training set: 0.352523305362
# Average coefficient of determination using 5-fold crossvalidation: 0.305752216433
#
#
# LINEAR :
# Coefficient of determination on training set: 0.352523305362
# Average coefficient of determination using 5-fold crossvalidation: 0.334507986296
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.835209048431
# Average coefficient of determination using 5-fold crossvalidation: -0.134351615475
#
#
# LASSO :
# Coefficient of determination on training set: 0.439375323488
# Average coefficient of determination using 5-fold crossvalidation: 0.395647340863
#
#
# LINEAR :
# Coefficient of determination on training set: 0.439375323488
# Average coefficient of determination using 5-fold crossvalidation: 0.368825800751
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.821029003754
# Average coefficient of determination using 5-fold crossvalidation: 0.0365923407138
#
#
# LASSO :
# Coefficient of determination on training set: 0.421781995231
# Average coefficient of determination using 5-fold crossvalidation: 0.325682113299
#
#
# LINEAR :
# Coefficient of determination on training set: 0.421781995231
# Average coefficient of determination using 5-fold crossvalidation: 0.321541545302
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.801451721021
# Average coefficient of determination using 5-fold crossvalidation: -0.11062541073
#
#
# LASSO :
# Coefficient of determination on training set: 0.375857458977
# Average coefficient of determination using 5-fold crossvalidation: 0.298912366429
#
#
# LINEAR :
# Coefficient of determination on training set: 0.375857458977
# Average coefficient of determination using 5-fold crossvalidation: 0.315337472748
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.815025813532
# Average coefficient of determination using 5-fold crossvalidation: -0.064425850314
#
#
# LASSO :
# Coefficient of determination on training set: 0.335246952171
# Average coefficient of determination using 5-fold crossvalidation: 0.230755837006
#
#
# LINEAR :
# Coefficient of determination on training set: 0.335246952171
# Average coefficient of determination using 5-fold crossvalidation: 0.274221099408
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.811619603867
# Average coefficient of determination using 5-fold crossvalidation: -0.185165364776
#
#
# LASSO :
# Coefficient of determination on training set: 0.369822690879
# Average coefficient of determination using 5-fold crossvalidation: 0.212690081993
#
#
# LINEAR :
# Coefficient of determination on training set: 0.369822690879
# Average coefficient of determination using 5-fold crossvalidation: 0.343326048438
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.833349011539
# Average coefficient of determination using 5-fold crossvalidation: -0.261527546376
#
#
# LASSO :
# Coefficient of determination on training set: 0.256290505967
# Average coefficient of determination using 5-fold crossvalidation: 0.157762390988
#
#
# LINEAR :
# Coefficient of determination on training set: 0.256290505967
# Average coefficient of determination using 5-fold crossvalidation: 0.230671071522
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.86005753526
# Average coefficient of determination using 5-fold crossvalidation: 0.122619969984
#
#
# LASSO :
# Coefficient of determination on training set: 0.522018872429
# Average coefficient of determination using 5-fold crossvalidation: 0.471426715676
#
#
# LINEAR :
# Coefficient of determination on training set: 0.522018872429
# Average coefficient of determination using 5-fold crossvalidation: 0.42538822427
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.771320423408
# Average coefficient of determination using 5-fold crossvalidation: -0.0331855759451
#
#
# LASSO :
# Coefficient of determination on training set: 0.361768164562
# Average coefficient of determination using 5-fold crossvalidation: 0.297040018638
#
#
# LINEAR :
# Coefficient of determination on training set: 0.361768164562
# Average coefficient of determination using 5-fold crossvalidation: 0.265341601808
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.872248140477
# Average coefficient of determination using 5-fold crossvalidation: -0.00555338011046
#
#
# LASSO :
# Coefficient of determination on training set: 0.48617324206
# Average coefficient of determination using 5-fold crossvalidation: 0.369847303668
#
#
# LINEAR :
# Coefficient of determination on training set: 0.48617324206
# Average coefficient of determination using 5-fold crossvalidation: 0.417467714773
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.775830832072
# Average coefficient of determination using 5-fold crossvalidation: -0.104870062974
#
#
# LASSO :
# Coefficient of determination on training set: 0.325480566642
# Average coefficient of determination using 5-fold crossvalidation: 0.281057049347
#
#
# LINEAR :
# Coefficient of determination on training set: 0.325480566642
# Average coefficient of determination using 5-fold crossvalidation: 0.28145533146
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.790670858392
# Average coefficient of determination using 5-fold crossvalidation: -0.288277683304
#
#
# LASSO :
# Coefficient of determination on training set: 0.370421394835
# Average coefficient of determination using 5-fold crossvalidation: 0.278197455828
#
#
# LINEAR :
# Coefficient of determination on training set: 0.370421394835
# Average coefficient of determination using 5-fold crossvalidation: 0.308535052899
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.828563071368
# Average coefficient of determination using 5-fold crossvalidation: -0.427809910051
#
#
# LASSO :
# Coefficient of determination on training set: 0.392872494298
# Average coefficient of determination using 5-fold crossvalidation: 0.34325737421
#
#
# LINEAR :
# Coefficient of determination on training set: 0.392872494298
# Average coefficient of determination using 5-fold crossvalidation: 0.313978560961
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.821627434918
# Average coefficient of determination using 5-fold crossvalidation: -0.213260948168
#
#
# LASSO :
# Coefficient of determination on training set: 0.34667936964
# Average coefficient of determination using 5-fold crossvalidation: 0.193943760746
#
#
# LINEAR :
# Coefficient of determination on training set: 0.34667936964
# Average coefficient of determination using 5-fold crossvalidation: 0.314616164584
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.841605982054
# Average coefficient of determination using 5-fold crossvalidation: -0.199936064348
#
#
# LASSO :
# Coefficient of determination on training set: 0.364354628316
# Average coefficient of determination using 5-fold crossvalidation: 0.341230897047
#
#
# LINEAR :
# Coefficient of determination on training set: 0.364354628316
# Average coefficient of determination using 5-fold crossvalidation: 0.359363230933
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.828015338285
# Average coefficient of determination using 5-fold crossvalidation: -0.20637809592
#
#
# LASSO :
# Coefficient of determination on training set: 0.353325381772
# Average coefficient of determination using 5-fold crossvalidation: 0.29268104039
#
#
# LINEAR :
# Coefficient of determination on training set: 0.353325381772
# Average coefficient of determination using 5-fold crossvalidation: 0.204811891934
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.871298339461
# Average coefficient of determination using 5-fold crossvalidation: -0.00998574535541
#
#
# LASSO :
# Coefficient of determination on training set: 0.42250102782
# Average coefficient of determination using 5-fold crossvalidation: 0.265936480684
#
#
# LINEAR :
# Coefficient of determination on training set: 0.42250102782
# Average coefficient of determination using 5-fold crossvalidation: 0.305589771345
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.811548856362
# Average coefficient of determination using 5-fold crossvalidation: -0.00434017294782
#
#
# LASSO :
# Coefficient of determination on training set: 0.3418563354
# Average coefficient of determination using 5-fold crossvalidation: 0.269677849564
#
#
# LINEAR :
# Coefficient of determination on training set: 0.3418563354
# Average coefficient of determination using 5-fold crossvalidation: 0.311841989912
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.840263249934
# Average coefficient of determination using 5-fold crossvalidation: 0.0187115211424
#
#
# LASSO :
# Coefficient of determination on training set: 0.468494115344
# Average coefficient of determination using 5-fold crossvalidation: 0.439946934342
#
#
# LINEAR :
# Coefficient of determination on training set: 0.468494115344
# Average coefficient of determination using 5-fold crossvalidation: 0.418297320618
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.833682552589
# Average coefficient of determination using 5-fold crossvalidation: 0.0308226362585
#
#
# LASSO :
# Coefficient of determination on training set: 0.285209409558
# Average coefficient of determination using 5-fold crossvalidation: 0.185658604343
#
#
# LINEAR :
# Coefficient of determination on training set: 0.285209409558
# Average coefficient of determination using 5-fold crossvalidation: 0.231001026298
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.794833967332
# Average coefficient of determination using 5-fold crossvalidation: -0.0306913486231
#
#
# LASSO :
# Coefficient of determination on training set: 0.379114762822
# Average coefficient of determination using 5-fold crossvalidation: 0.317638562508
#
#
# LINEAR :
# Coefficient of determination on training set: 0.379114762822
# Average coefficient of determination using 5-fold crossvalidation: 0.354297811835
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.831639466335
# Average coefficient of determination using 5-fold crossvalidation: -0.0313788248648
#
#
# LASSO :
# Coefficient of determination on training set: 0.395514254043
# Average coefficient of determination using 5-fold crossvalidation: 0.309862701192
#
#
# LINEAR :
# Coefficient of determination on training set: 0.395514254043
# Average coefficient of determination using 5-fold crossvalidation: 0.365250347963
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.845754415695
# Average coefficient of determination using 5-fold crossvalidation: -0.0475115846607
#
#
# LASSO :
# Coefficient of determination on training set: 0.420540427242
# Average coefficient of determination using 5-fold crossvalidation: 0.323006344307
#
#
# LINEAR :
# Coefficient of determination on training set: 0.420540427242
# Average coefficient of determination using 5-fold crossvalidation: 0.321252453959
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.749408860151
# Average coefficient of determination using 5-fold crossvalidation: -0.187412778956
#
#
# LASSO :
# Coefficient of determination on training set: 0.353664259632
# Average coefficient of determination using 5-fold crossvalidation: 0.239425860323
#
#
# LINEAR :
# Coefficient of determination on training set: 0.353664259632
# Average coefficient of determination using 5-fold crossvalidation: 0.309139134751
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.763192016373
# Average coefficient of determination using 5-fold crossvalidation: -0.233748878723
#
#
# LASSO :
# Coefficient of determination on training set: 0.343307258469
# Average coefficient of determination using 5-fold crossvalidation: 0.287425380545
#
#
# LINEAR :
# Coefficient of determination on training set: 0.343307258469
# Average coefficient of determination using 5-fold crossvalidation: 0.234565509345
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.819050400908
# Average coefficient of determination using 5-fold crossvalidation: -0.292639212858
#
#
# LASSO :
# Coefficient of determination on training set: 0.345901316857
# Average coefficient of determination using 5-fold crossvalidation: 0.238489850734
#
#
# LINEAR :
# Coefficient of determination on training set: 0.345901316857
# Average coefficient of determination using 5-fold crossvalidation: 0.0609210736945
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.850014856324
# Average coefficient of determination using 5-fold crossvalidation: 0.0611262280321
#
#
# LASSO :
# Coefficient of determination on training set: 0.423363218753
# Average coefficient of determination using 5-fold crossvalidation: 0.3251075435
#
#
# LINEAR :
# Coefficient of determination on training set: 0.423363218753
# Average coefficient of determination using 5-fold crossvalidation: 0.353951414591
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.821689517201
# Average coefficient of determination using 5-fold crossvalidation: 0.133870612667
#
#
# LASSO :
# Coefficient of determination on training set: 0.37641242301
# Average coefficient of determination using 5-fold crossvalidation: 0.269076225258
#
#
# LINEAR :
# Coefficient of determination on training set: 0.37641242301
# Average coefficient of determination using 5-fold crossvalidation: 0.280290093363
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.863044287913
# Average coefficient of determination using 5-fold crossvalidation: 0.0757524385375
#
#
# LASSO :
# Coefficient of determination on training set: 0.358223292033
# Average coefficient of determination using 5-fold crossvalidation: 0.317826014808
#
#
# LINEAR :
# Coefficient of determination on training set: 0.358223292033
# Average coefficient of determination using 5-fold crossvalidation: 0.277045375917
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.786759994905
# Average coefficient of determination using 5-fold crossvalidation: -0.0763011387612
#
#
# LASSO :
# Coefficient of determination on training set: 0.381064558015
# Average coefficient of determination using 5-fold crossvalidation: 0.312198218562
#
#
# LINEAR :
# Coefficient of determination on training set: 0.381064558015
# Average coefficient of determination using 5-fold crossvalidation: 0.326371759076
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.830836041348
# Average coefficient of determination using 5-fold crossvalidation: 0.069791938276
#
#
# LASSO :
# Coefficient of determination on training set: 0.401700673688
# Average coefficient of determination using 5-fold crossvalidation: 0.369635286575
#
#
# LINEAR :
# Coefficient of determination on training set: 0.401700673688
# Average coefficient of determination using 5-fold crossvalidation: 0.37516164995
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.834376312849
# Average coefficient of determination using 5-fold crossvalidation: -0.130498917794
#
#
# LASSO :
# Coefficient of determination on training set: 0.412307880504
# Average coefficient of determination using 5-fold crossvalidation: 0.369247762789
#
#
# LINEAR :
# Coefficient of determination on training set: 0.412307880504
# Average coefficient of determination using 5-fold crossvalidation: 0.37714756237
#
#
# Index(['AdjEM_x-y'], dtype='object')
# RF :
# Coefficient of determination on training set: 0.7796600962
# Average coefficient of determination using 5-fold crossvalidation: -0.294296660324
#
#
# LASSO :
# Coefficient of determination on training set: 0.376893437113
# Average coefficient of determination using 5-fold crossvalidation: 0.308488467567
#
#
# LINEAR :
# Coefficient of determination on training set: 0.376893437113
# Average coefficient of determination using 5-fold crossvalidation: 0.290664329403

# %% [markdown]
# ## Binary Classification (SVM): Using Game Result as Response Variable

# %%
def powerset(seq):
    """
    Returns all the subsets of this set. This is a generator.
    """
    if len(seq) <= 1:
        yield seq
        yield []
    else:
        for item in powerset(seq[1:]):
            yield [seq[0]]+item
            yield item
            
feature_list_pre = powerset(list(d['master'])[2:17])
feature_list_pre = list(feature_list_pre)

# %%
len(feature_list)
# Out:
# 575

# %%
feature_list = list()

for i in range(len(feature_list_pre)):
    if len(feature_list_pre[i])<=3 and len(feature_list_pre[i])>=1:
        feature_list.append(feature_list_pre[i])

# %%
np.mean([1,2,3])
# Out:
# 2.0

# %%
feature_r_squared = dict()

for feature in feature_list:
    X = np.array(d['master'][feature]) 
    y = np.array(d['master']['result'])

    r_squared_lst = []
    for i in range(100):
        X_train, X_test, y_train, y_test = cross_validation.train_test_split(X, y, test_size=0.15)

        clf = svm.SVC()
        clf.fit(X_train, y_train)
        
        cv = KFold(X_train.shape[0], 10, shuffle = True)
        r_squared = cross_val_score(clf, X_train, y_train, cv = cv)
        r_squared = np.mean(r_squared)
        r_squared_lst.append(r_squared)
    print ("Average confidence w/ 100 repetitions for ", feature, "w/ 5-fold CV :", sum(r_squared_lst)/len(r_squared_lst))
    feature_r_squared[str(feature)] = sum(r_squared_lst)/len(r_squared_lst)
# Out:
# Average confidence w/ 100 repetitions for  ['PT_Ratio_x-y', 'True_S_x-y', 'seed_x-y'] w/ 5-fold CV : 0.723742690058
# Average confidence w/ 100 repetitions for  ['OPPO_pt_x-y', 'True_S_x-y', 'seed_x-y'] w/ 5-fold CV : 0.733426900585
# Average confidence w/ 100 repetitions for  ['TM_pt_x-y', 'True_S_x-y', 'seed_x-y'] w/ 5-fold CV : 0.738514619883
# Average confidence w/ 100 repetitions for  ['SOS_x-y', 'True_S_x-y', 'seed_x-y'] w/ 5-fold CV : 0.736485380117
# Average confidence w/ 100 repetitions for  ['SRS_x-y', 'True_S_x-y', 'seed_x-y'] w/ 5-fold CV : 0.738871345029
# Average confidence w/ 100 repetitions for  ['W_L_ratio_x-y', 'True_S_x-y', 'seed_x-y'] w/ 5-fold CV : 0.723298245614
# Average confidence w/ 100 repetitions for  ['L_x-y', 'True_S_x-y', 'seed_x-y'] w/ 5-fold CV : 0.682043859649
# Average confidence w/ 100 repetitions for  ['W_x-y', 'True_S_x-y', 'seed_x-y'] w/ 5-fold CV : 0.767540935673
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'True_S_x-y', 'seed_x-y'] w/ 5-fold CV : 0.725040935673
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'True_S_x-y', 'seed_x-y'] w/ 5-fold CV : 0.710950292398
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'True_S_x-y', 'seed_x-y'] w/ 5-fold CV : 0.720301169591
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'True_S_x-y', 'seed_x-y'] w/ 5-fold CV : 0.697122807018
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'True_S_x-y', 'seed_x-y'] w/ 5-fold CV : 0.739669590643
# Average confidence w/ 100 repetitions for  ['True_S_x-y', 'seed_x-y'] w/ 5-fold CV : 0.718441520468
# Average confidence w/ 100 repetitions for  ['OPPO_pt_x-y', 'PT_Ratio_x-y', 'seed_x-y'] w/ 5-fold CV : 0.735842105263
# Average confidence w/ 100 repetitions for  ['TM_pt_x-y', 'PT_Ratio_x-y', 'seed_x-y'] w/ 5-fold CV : 0.739546783626
# Average confidence w/ 100 repetitions for  ['SOS_x-y', 'PT_Ratio_x-y', 'seed_x-y'] w/ 5-fold CV : 0.736470760234
# Average confidence w/ 100 repetitions for  ['SRS_x-y', 'PT_Ratio_x-y', 'seed_x-y'] w/ 5-fold CV : 0.739581871345
# Average confidence w/ 100 repetitions for  ['W_L_ratio_x-y', 'PT_Ratio_x-y', 'seed_x-y'] w/ 5-fold CV : 0.722687134503
# Average confidence w/ 100 repetitions for  ['L_x-y', 'PT_Ratio_x-y', 'seed_x-y'] w/ 5-fold CV : 0.680333333333
# Average confidence w/ 100 repetitions for  ['W_x-y', 'PT_Ratio_x-y', 'seed_x-y'] w/ 5-fold CV : 0.765081871345
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'PT_Ratio_x-y', 'seed_x-y'] w/ 5-fold CV : 0.726728070175
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'PT_Ratio_x-y', 'seed_x-y'] w/ 5-fold CV : 0.70951754386
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'PT_Ratio_x-y', 'seed_x-y'] w/ 5-fold CV : 0.720038011696
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'PT_Ratio_x-y', 'seed_x-y'] w/ 5-fold CV : 0.703847953216
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'PT_Ratio_x-y', 'seed_x-y'] w/ 5-fold CV : 0.738035087719
# Average confidence w/ 100 repetitions for  ['PT_Ratio_x-y', 'seed_x-y'] w/ 5-fold CV : 0.718035087719
# Average confidence w/ 100 repetitions for  ['TM_pt_x-y', 'OPPO_pt_x-y', 'seed_x-y'] w/ 5-fold CV : 0.74565497076
# Average confidence w/ 100 repetitions for  ['SOS_x-y', 'OPPO_pt_x-y', 'seed_x-y'] w/ 5-fold CV : 0.743266081871
# Average confidence w/ 100 repetitions for  ['SRS_x-y', 'OPPO_pt_x-y', 'seed_x-y'] w/ 5-fold CV : 0.743555555556
# Average confidence w/ 100 repetitions for  ['W_L_ratio_x-y', 'OPPO_pt_x-y', 'seed_x-y'] w/ 5-fold CV : 0.730722222222
# Average confidence w/ 100 repetitions for  ['L_x-y', 'OPPO_pt_x-y', 'seed_x-y'] w/ 5-fold CV : 0.743453216374
# Average confidence w/ 100 repetitions for  ['W_x-y', 'OPPO_pt_x-y', 'seed_x-y'] w/ 5-fold CV : 0.745754385965
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'OPPO_pt_x-y', 'seed_x-y'] w/ 5-fold CV : 0.732540935673
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'OPPO_pt_x-y', 'seed_x-y'] w/ 5-fold CV : 0.741438596491
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'OPPO_pt_x-y', 'seed_x-y'] w/ 5-fold CV : 0.743643274854
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'OPPO_pt_x-y', 'seed_x-y'] w/ 5-fold CV : 0.744423976608
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'OPPO_pt_x-y', 'seed_x-y'] w/ 5-fold CV : 0.738660818713
# Average confidence w/ 100 repetitions for  ['OPPO_pt_x-y', 'seed_x-y'] w/ 5-fold CV : 0.73649122807
# Average confidence w/ 100 repetitions for  ['SOS_x-y', 'TM_pt_x-y', 'seed_x-y'] w/ 5-fold CV : 0.742941520468
# Average confidence w/ 100 repetitions for  ['SRS_x-y', 'TM_pt_x-y', 'seed_x-y'] w/ 5-fold CV : 0.743333333333
# Average confidence w/ 100 repetitions for  ['W_L_ratio_x-y', 'TM_pt_x-y', 'seed_x-y'] w/ 5-fold CV : 0.739830409357
# Average confidence w/ 100 repetitions for  ['L_x-y', 'TM_pt_x-y', 'seed_x-y'] w/ 5-fold CV : 0.741421052632
# Average confidence w/ 100 repetitions for  ['W_x-y', 'TM_pt_x-y', 'seed_x-y'] w/ 5-fold CV : 0.742429824561
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'TM_pt_x-y', 'seed_x-y'] w/ 5-fold CV : 0.740260233918
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'TM_pt_x-y', 'seed_x-y'] w/ 5-fold CV : 0.743046783626
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'TM_pt_x-y', 'seed_x-y'] w/ 5-fold CV : 0.743953216374
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'TM_pt_x-y', 'seed_x-y'] w/ 5-fold CV : 0.742926900585
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'TM_pt_x-y', 'seed_x-y'] w/ 5-fold CV : 0.746122807018
# Average confidence w/ 100 repetitions for  ['TM_pt_x-y', 'seed_x-y'] w/ 5-fold CV : 0.742184210526
# Average confidence w/ 100 repetitions for  ['SRS_x-y', 'SOS_x-y', 'seed_x-y'] w/ 5-fold CV : 0.75569005848
# Average confidence w/ 100 repetitions for  ['W_L_ratio_x-y', 'SOS_x-y', 'seed_x-y'] w/ 5-fold CV : 0.741725146199
# Average confidence w/ 100 repetitions for  ['L_x-y', 'SOS_x-y', 'seed_x-y'] w/ 5-fold CV : 0.745757309942
# Average confidence w/ 100 repetitions for  ['W_x-y', 'SOS_x-y', 'seed_x-y'] w/ 5-fold CV : 0.775160818713
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'SOS_x-y', 'seed_x-y'] w/ 5-fold CV : 0.736377192982
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'SOS_x-y', 'seed_x-y'] w/ 5-fold CV : 0.72448245614
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'SOS_x-y', 'seed_x-y'] w/ 5-fold CV : 0.751666666667
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'SOS_x-y', 'seed_x-y'] w/ 5-fold CV : 0.737988304094
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'SOS_x-y', 'seed_x-y'] w/ 5-fold CV : 0.7615
# Average confidence w/ 100 repetitions for  ['SOS_x-y', 'seed_x-y'] w/ 5-fold CV : 0.738523391813
# Average confidence w/ 100 repetitions for  ['W_L_ratio_x-y', 'SRS_x-y', 'seed_x-y'] w/ 5-fold CV : 0.741271929825
# Average confidence w/ 100 repetitions for  ['L_x-y', 'SRS_x-y', 'seed_x-y'] w/ 5-fold CV : 0.733555555556
# Average confidence w/ 100 repetitions for  ['W_x-y', 'SRS_x-y', 'seed_x-y'] w/ 5-fold CV : 0.738505847953
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'SRS_x-y', 'seed_x-y'] w/ 5-fold CV : 0.73917251462
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'SRS_x-y', 'seed_x-y'] w/ 5-fold CV : 0.72933625731
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'SRS_x-y', 'seed_x-y'] w/ 5-fold CV : 0.737254385965
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'SRS_x-y', 'seed_x-y'] w/ 5-fold CV : 0.722283625731
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'SRS_x-y', 'seed_x-y'] w/ 5-fold CV : 0.732716374269
# Average confidence w/ 100 repetitions for  ['SRS_x-y', 'seed_x-y'] w/ 5-fold CV : 0.738263157895
# Average confidence w/ 100 repetitions for  ['L_x-y', 'W_L_ratio_x-y', 'seed_x-y'] w/ 5-fold CV : 0.683032163743
# Average confidence w/ 100 repetitions for  ['W_x-y', 'W_L_ratio_x-y', 'seed_x-y'] w/ 5-fold CV : 0.7665
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'W_L_ratio_x-y', 'seed_x-y'] w/ 5-fold CV : 0.719578947368
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'W_L_ratio_x-y', 'seed_x-y'] w/ 5-fold CV : 0.704274853801
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'W_L_ratio_x-y', 'seed_x-y'] w/ 5-fold CV : 0.718883040936
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'W_L_ratio_x-y', 'seed_x-y'] w/ 5-fold CV : 0.701251461988
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'W_L_ratio_x-y', 'seed_x-y'] w/ 5-fold CV : 0.739959064327
# Average confidence w/ 100 repetitions for  ['W_L_ratio_x-y', 'seed_x-y'] w/ 5-fold CV : 0.722970760234
# Average confidence w/ 100 repetitions for  ['W_x-y', 'L_x-y', 'seed_x-y'] w/ 5-fold CV : 0.772385964912
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'L_x-y', 'seed_x-y'] w/ 5-fold CV : 0.684678362573
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'L_x-y', 'seed_x-y'] w/ 5-fold CV : 0.72850877193
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'L_x-y', 'seed_x-y'] w/ 5-fold CV : 0.748456140351
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'L_x-y', 'seed_x-y'] w/ 5-fold CV : 0.730400584795
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'L_x-y', 'seed_x-y'] w/ 5-fold CV : 0.723985380117
# Average confidence w/ 100 repetitions for  ['L_x-y', 'seed_x-y'] w/ 5-fold CV : 0.678736842105
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'W_x-y', 'seed_x-y'] w/ 5-fold CV : 0.764701754386
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'W_x-y', 'seed_x-y'] w/ 5-fold CV : 0.771488304094
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'W_x-y', 'seed_x-y'] w/ 5-fold CV : 0.737520467836
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'W_x-y', 'seed_x-y'] w/ 5-fold CV : 0.767561403509
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'W_x-y', 'seed_x-y'] w/ 5-fold CV : 0.759815789474
# Average confidence w/ 100 repetitions for  ['W_x-y', 'seed_x-y'] w/ 5-fold CV : 0.754029239766
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'luck_x-y', 'seed_x-y'] w/ 5-fold CV : 0.709871345029
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'luck_x-y', 'seed_x-y'] w/ 5-fold CV : 0.720807017544
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'luck_x-y', 'seed_x-y'] w/ 5-fold CV : 0.706549707602
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'luck_x-y', 'seed_x-y'] w/ 5-fold CV : 0.736169590643
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'seed_x-y'] w/ 5-fold CV : 0.715967836257
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'AdjT_x-y', 'seed_x-y'] w/ 5-fold CV : 0.722923976608
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'AdjT_x-y', 'seed_x-y'] w/ 5-fold CV : 0.718330409357
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'AdjT_x-y', 'seed_x-y'] w/ 5-fold CV : 0.723219298246
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'seed_x-y'] w/ 5-fold CV : 0.717660818713
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'AdjD_x-y', 'seed_x-y'] w/ 5-fold CV : 0.743666666667
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'AdjD_x-y', 'seed_x-y'] w/ 5-fold CV : 0.74718128655
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'seed_x-y'] w/ 5-fold CV : 0.721821637427
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'AdjO_x-y', 'seed_x-y'] w/ 5-fold CV : 0.730090643275
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'seed_x-y'] w/ 5-fold CV : 0.70768128655
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'seed_x-y'] w/ 5-fold CV : 0.740216374269
# Average confidence w/ 100 repetitions for  ['seed_x-y'] w/ 5-fold CV : 0.716245614035
# Average confidence w/ 100 repetitions for  ['OPPO_pt_x-y', 'PT_Ratio_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.708450292398
# Average confidence w/ 100 repetitions for  ['TM_pt_x-y', 'PT_Ratio_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.716529239766
# Average confidence w/ 100 repetitions for  ['SOS_x-y', 'PT_Ratio_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.726502923977
# Average confidence w/ 100 repetitions for  ['SRS_x-y', 'PT_Ratio_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.732423976608
# Average confidence w/ 100 repetitions for  ['W_L_ratio_x-y', 'PT_Ratio_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.741233918129
# Average confidence w/ 100 repetitions for  ['L_x-y', 'PT_Ratio_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.741377192982
# Average confidence w/ 100 repetitions for  ['W_x-y', 'PT_Ratio_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.767751461988
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'PT_Ratio_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.743637426901
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'PT_Ratio_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.743453216374
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'PT_Ratio_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.730011695906
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'PT_Ratio_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.716076023392
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'PT_Ratio_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.762865497076
# Average confidence w/ 100 repetitions for  ['PT_Ratio_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.742859649123
# Average confidence w/ 100 repetitions for  ['TM_pt_x-y', 'OPPO_pt_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.743953216374
# Average confidence w/ 100 repetitions for  ['SOS_x-y', 'OPPO_pt_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.740894736842
# Average confidence w/ 100 repetitions for  ['SRS_x-y', 'OPPO_pt_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.734918128655
# Average confidence w/ 100 repetitions for  ['W_L_ratio_x-y', 'OPPO_pt_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.702970760234
# Average confidence w/ 100 repetitions for  ['L_x-y', 'OPPO_pt_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.739757309942
# Average confidence w/ 100 repetitions for  ['W_x-y', 'OPPO_pt_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.739038011696
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'OPPO_pt_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.701590643275
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'OPPO_pt_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.746260233918
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'OPPO_pt_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.741476608187
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'OPPO_pt_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.743883040936
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'OPPO_pt_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.737824561404
# Average confidence w/ 100 repetitions for  ['OPPO_pt_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.728307017544
# Average confidence w/ 100 repetitions for  ['SOS_x-y', 'TM_pt_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.750409356725
# Average confidence w/ 100 repetitions for  ['SRS_x-y', 'TM_pt_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.742423976608
# Average confidence w/ 100 repetitions for  ['W_L_ratio_x-y', 'TM_pt_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.717839181287
# Average confidence w/ 100 repetitions for  ['L_x-y', 'TM_pt_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.740052631579
# Average confidence w/ 100 repetitions for  ['W_x-y', 'TM_pt_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.745102339181
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'TM_pt_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.714725146199
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'TM_pt_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.733321637427
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'TM_pt_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.747
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'TM_pt_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.730865497076
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'TM_pt_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.741801169591
# Average confidence w/ 100 repetitions for  ['TM_pt_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.728760233918
# Average confidence w/ 100 repetitions for  ['SRS_x-y', 'SOS_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.72651754386
# Average confidence w/ 100 repetitions for  ['W_L_ratio_x-y', 'SOS_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.727073099415
# Average confidence w/ 100 repetitions for  ['L_x-y', 'SOS_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.740926900585
# Average confidence w/ 100 repetitions for  ['W_x-y', 'SOS_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.780745614035
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'SOS_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.730046783626
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'SOS_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.71798245614
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'SOS_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.740049707602
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'SOS_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.71301754386
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'SOS_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.726055555556
# Average confidence w/ 100 repetitions for  ['SOS_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.722450292398
# Average confidence w/ 100 repetitions for  ['W_L_ratio_x-y', 'SRS_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.728418128655
# Average confidence w/ 100 repetitions for  ['L_x-y', 'SRS_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.701578947368
# Average confidence w/ 100 repetitions for  ['W_x-y', 'SRS_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.745871345029
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'SRS_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.729453216374
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'SRS_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.702578947368
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'SRS_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.731140350877
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'SRS_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.720207602339
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'SRS_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.722964912281
# Average confidence w/ 100 repetitions for  ['SRS_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.725783625731
# Average confidence w/ 100 repetitions for  ['L_x-y', 'W_L_ratio_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.740169590643
# Average confidence w/ 100 repetitions for  ['W_x-y', 'W_L_ratio_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.773970760234
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'W_L_ratio_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.744532163743
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'W_L_ratio_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.742040935673
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'W_L_ratio_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.730710526316
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'W_L_ratio_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.717397660819
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'W_L_ratio_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.762321637427
# Average confidence w/ 100 repetitions for  ['W_L_ratio_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.743122807018
# Average confidence w/ 100 repetitions for  ['W_x-y', 'L_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.789976608187
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'L_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.742157894737
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'L_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.741219298246
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'L_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.736111111111
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'L_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.737745614035
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'L_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.727695906433
# Average confidence w/ 100 repetitions for  ['L_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.736880116959
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'W_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.765611111111
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'W_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.794546783626
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'W_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.748029239766
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'W_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.757479532164
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'W_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.762020467836
# Average confidence w/ 100 repetitions for  ['W_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.765137426901
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'luck_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.746707602339
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'luck_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.728590643275
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'luck_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.716973684211
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'luck_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.761599415205
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.742976608187
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'AdjT_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.749149122807
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'AdjT_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.71518128655
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'AdjT_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.730640350877
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.742029239766
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'AdjD_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.732412280702
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'AdjD_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.743359649123
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.736122807018
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'AdjO_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.742540935673
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.717459064327
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'True_S_x-y'] w/ 5-fold CV : 0.756754385965
# Average confidence w/ 100 repetitions for  ['True_S_x-y'] w/ 5-fold CV : 0.745137426901
# Average confidence w/ 100 repetitions for  ['TM_pt_x-y', 'OPPO_pt_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.744751461988
# Average confidence w/ 100 repetitions for  ['SOS_x-y', 'OPPO_pt_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.740266081871
# Average confidence w/ 100 repetitions for  ['SRS_x-y', 'OPPO_pt_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.736847953216
# Average confidence w/ 100 repetitions for  ['W_L_ratio_x-y', 'OPPO_pt_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.70601754386
# Average confidence w/ 100 repetitions for  ['L_x-y', 'OPPO_pt_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.740266081871
# Average confidence w/ 100 repetitions for  ['W_x-y', 'OPPO_pt_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.73882748538
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'OPPO_pt_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.704692982456
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'OPPO_pt_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.743909356725
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'OPPO_pt_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.740856725146
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'OPPO_pt_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.745149122807
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'OPPO_pt_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.738578947368
# Average confidence w/ 100 repetitions for  ['OPPO_pt_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.724511695906
# Average confidence w/ 100 repetitions for  ['SOS_x-y', 'TM_pt_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.750833333333
# Average confidence w/ 100 repetitions for  ['SRS_x-y', 'TM_pt_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.74598245614
# Average confidence w/ 100 repetitions for  ['W_L_ratio_x-y', 'TM_pt_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.714052631579
# Average confidence w/ 100 repetitions for  ['L_x-y', 'TM_pt_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.739383040936
# Average confidence w/ 100 repetitions for  ['W_x-y', 'TM_pt_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.746143274854
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'TM_pt_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.713874269006
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'TM_pt_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.732812865497
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'TM_pt_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.748418128655
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'TM_pt_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.732570175439
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'TM_pt_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.740023391813
# Average confidence w/ 100 repetitions for  ['TM_pt_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.728476608187
# Average confidence w/ 100 repetitions for  ['SRS_x-y', 'SOS_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.727090643275
# Average confidence w/ 100 repetitions for  ['W_L_ratio_x-y', 'SOS_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.729198830409
# Average confidence w/ 100 repetitions for  ['L_x-y', 'SOS_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.743979532164
# Average confidence w/ 100 repetitions for  ['W_x-y', 'SOS_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.777321637427
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'SOS_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.729573099415
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'SOS_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.716394736842
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'SOS_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.738929824561
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'SOS_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.717429824561
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'SOS_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.726736842105
# Average confidence w/ 100 repetitions for  ['SOS_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.723994152047
# Average confidence w/ 100 repetitions for  ['W_L_ratio_x-y', 'SRS_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.733561403509
# Average confidence w/ 100 repetitions for  ['L_x-y', 'SRS_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.704380116959
# Average confidence w/ 100 repetitions for  ['W_x-y', 'SRS_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.740763157895
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'SRS_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.728011695906
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'SRS_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.698116959064
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'SRS_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.725608187135
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'SRS_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.720149122807
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'SRS_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.721842105263
# Average confidence w/ 100 repetitions for  ['SRS_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.727195906433
# Average confidence w/ 100 repetitions for  ['L_x-y', 'W_L_ratio_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.740096491228
# Average confidence w/ 100 repetitions for  ['W_x-y', 'W_L_ratio_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.767096491228
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'W_L_ratio_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.743114035088
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'W_L_ratio_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.74268128655
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'W_L_ratio_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.728149122807
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'W_L_ratio_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.715260233918
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'W_L_ratio_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.760912280702
# Average confidence w/ 100 repetitions for  ['W_L_ratio_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.744716374269
# Average confidence w/ 100 repetitions for  ['W_x-y', 'L_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.788912280702
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'L_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.74
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'L_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.736745614035
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'L_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.737976608187
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'L_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.734549707602
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'L_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.725260233918
# Average confidence w/ 100 repetitions for  ['L_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.738198830409
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'W_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.76985380117
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'W_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.796116959064
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'W_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.748406432749
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'W_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.755081871345
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'W_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.765406432749
# Average confidence w/ 100 repetitions for  ['W_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.76631871345
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'luck_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.744304093567
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'luck_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.728485380117
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'luck_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.717652046784
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'luck_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.761225146199
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.743807017544
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'AdjT_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.748406432749
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'AdjT_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.716087719298
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'AdjT_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.728342105263
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.744125730994
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'AdjD_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.734251461988
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'AdjD_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.732526315789
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.738988304094
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'AdjO_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.741804093567
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.714046783626
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'PT_Ratio_x-y'] w/ 5-fold CV : 0.758520467836
# Average confidence w/ 100 repetitions for  ['PT_Ratio_x-y'] w/ 5-fold CV : 0.74299122807
# Average confidence w/ 100 repetitions for  ['SOS_x-y', 'TM_pt_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.744719298246
# Average confidence w/ 100 repetitions for  ['SRS_x-y', 'TM_pt_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.740652046784
# Average confidence w/ 100 repetitions for  ['W_L_ratio_x-y', 'TM_pt_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.743169590643
# Average confidence w/ 100 repetitions for  ['L_x-y', 'TM_pt_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.742374269006
# Average confidence w/ 100 repetitions for  ['W_x-y', 'TM_pt_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.743967836257
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'TM_pt_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.741956140351
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'TM_pt_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.745
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'TM_pt_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.744073099415
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'TM_pt_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.741757309942
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'TM_pt_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.744076023392
# Average confidence w/ 100 repetitions for  ['TM_pt_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.743055555556
# Average confidence w/ 100 repetitions for  ['SRS_x-y', 'SOS_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.74399122807
# Average confidence w/ 100 repetitions for  ['W_L_ratio_x-y', 'SOS_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.73982748538
# Average confidence w/ 100 repetitions for  ['L_x-y', 'SOS_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.743804093567
# Average confidence w/ 100 repetitions for  ['W_x-y', 'SOS_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.741824561404
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'SOS_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.737944444444
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'SOS_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.742409356725
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'SOS_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.743883040936
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'SOS_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.744497076023
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'SOS_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.742988304094
# Average confidence w/ 100 repetitions for  ['SOS_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.742538011696
# Average confidence w/ 100 repetitions for  ['W_L_ratio_x-y', 'SRS_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.732295321637
# Average confidence w/ 100 repetitions for  ['L_x-y', 'SRS_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.743081871345
# Average confidence w/ 100 repetitions for  ['W_x-y', 'SRS_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.743543859649
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'SRS_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.735055555556
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'SRS_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.74419005848
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'SRS_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.741684210526
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'SRS_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.743441520468
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'SRS_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.74149122807
# Average confidence w/ 100 repetitions for  ['SRS_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.738748538012
# Average confidence w/ 100 repetitions for  ['L_x-y', 'W_L_ratio_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.737912280702
# Average confidence w/ 100 repetitions for  ['W_x-y', 'W_L_ratio_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.742619883041
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'W_L_ratio_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.703236842105
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'W_L_ratio_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.745880116959
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'W_L_ratio_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.744716374269
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'W_L_ratio_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.746538011696
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'W_L_ratio_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.738356725146
# Average confidence w/ 100 repetitions for  ['W_L_ratio_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.725122807018
# Average confidence w/ 100 repetitions for  ['W_x-y', 'L_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.740002923977
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'L_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.739222222222
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'L_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.743377192982
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'L_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.745687134503
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'L_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.750710526316
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'L_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.744248538012
# Average confidence w/ 100 repetitions for  ['L_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.740730994152
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'W_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.738815789474
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'W_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.74364619883
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'W_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.744374269006
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'W_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.743649122807
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'W_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.743549707602
# Average confidence w/ 100 repetitions for  ['W_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.741652046784
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'luck_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.742807017544
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'luck_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.741915204678
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'luck_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.747070175439
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'luck_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.737584795322
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.725894736842
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'AdjT_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.742903508772
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'AdjT_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.743637426901
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'AdjT_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.741944444444
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.740915204678
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'AdjD_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.743938596491
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'AdjD_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.742795321637
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.736801169591
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'AdjO_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.742839181287
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.744371345029
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'OPPO_pt_x-y'] w/ 5-fold CV : 0.740055555556
# Average confidence w/ 100 repetitions for  ['OPPO_pt_x-y'] w/ 5-fold CV : 0.717283625731
# Average confidence w/ 100 repetitions for  ['SRS_x-y', 'SOS_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.743067251462
# Average confidence w/ 100 repetitions for  ['W_L_ratio_x-y', 'SOS_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.74830994152
# Average confidence w/ 100 repetitions for  ['L_x-y', 'SOS_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.742558479532
# Average confidence w/ 100 repetitions for  ['W_x-y', 'SOS_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.741429824561
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'SOS_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.74998245614
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'SOS_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.745418128655
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'SOS_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.740090643275
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'SOS_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.743485380117
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'SOS_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.744891812865
# Average confidence w/ 100 repetitions for  ['SOS_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.752324561404
# Average confidence w/ 100 repetitions for  ['W_L_ratio_x-y', 'SRS_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.742888888889
# Average confidence w/ 100 repetitions for  ['L_x-y', 'SRS_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.741257309942
# Average confidence w/ 100 repetitions for  ['W_x-y', 'SRS_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.740578947368
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'SRS_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.744242690058
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'SRS_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.743488304094
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'SRS_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.741453216374
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'SRS_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.743953216374
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'SRS_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.744330409357
# Average confidence w/ 100 repetitions for  ['SRS_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.744137426901
# Average confidence w/ 100 repetitions for  ['L_x-y', 'W_L_ratio_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.738423976608
# Average confidence w/ 100 repetitions for  ['W_x-y', 'W_L_ratio_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.744640350877
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'W_L_ratio_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.717201754386
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'W_L_ratio_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.736143274854
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'W_L_ratio_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.743909356725
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'W_L_ratio_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.735751461988
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'W_L_ratio_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.739821637427
# Average confidence w/ 100 repetitions for  ['W_L_ratio_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.725406432749
# Average confidence w/ 100 repetitions for  ['W_x-y', 'L_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.740169590643
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'L_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.741634502924
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'L_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.745649122807
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'L_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.74264619883
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'L_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.741368421053
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'L_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.738698830409
# Average confidence w/ 100 repetitions for  ['L_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.740719298246
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'W_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.746807017544
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'W_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.744026315789
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'W_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.751228070175
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'W_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.738961988304
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'W_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.743157894737
# Average confidence w/ 100 repetitions for  ['W_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.744391812865
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'luck_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.734488304094
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'luck_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.746897660819
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'luck_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.735543859649
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'luck_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.740137426901
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.728666666667
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'AdjT_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.743093567251
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'AdjT_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.74049122807
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'AdjT_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.745111111111
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.742628654971
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'AdjD_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.743032163743
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'AdjD_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.742608187135
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.742558479532
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'AdjO_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.743719298246
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.73583625731
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'TM_pt_x-y'] w/ 5-fold CV : 0.741605263158
# Average confidence w/ 100 repetitions for  ['TM_pt_x-y'] w/ 5-fold CV : 0.721260233918
# Average confidence w/ 100 repetitions for  ['W_L_ratio_x-y', 'SRS_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.732289473684
# Average confidence w/ 100 repetitions for  ['L_x-y', 'SRS_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.737584795322
# Average confidence w/ 100 repetitions for  ['W_x-y', 'SRS_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.750716374269
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'SRS_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.728710526316
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'SRS_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.72318128655
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'SRS_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.744330409357
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'SRS_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.721222222222
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'SRS_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.73785380117
# Average confidence w/ 100 repetitions for  ['SRS_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.726324561404
# Average confidence w/ 100 repetitions for  ['L_x-y', 'W_L_ratio_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.747859649123
# Average confidence w/ 100 repetitions for  ['W_x-y', 'W_L_ratio_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.782570175439
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'W_L_ratio_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.73
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'W_L_ratio_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.718883040936
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'W_L_ratio_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.740409356725
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'W_L_ratio_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.718175438596
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'W_L_ratio_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.728625730994
# Average confidence w/ 100 repetitions for  ['W_L_ratio_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.722485380117
# Average confidence w/ 100 repetitions for  ['W_x-y', 'L_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.780555555556
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'L_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.74114619883
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'L_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.736339181287
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'L_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.756090643275
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'L_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.734099415205
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'L_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.748105263158
# Average confidence w/ 100 repetitions for  ['L_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.73714619883
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'W_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.783236842105
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'W_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.766219298246
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'W_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.76130994152
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'W_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.730362573099
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'W_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.741871345029
# Average confidence w/ 100 repetitions for  ['W_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.767298245614
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'luck_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.714035087719
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'luck_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.743660818713
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'luck_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.716874269006
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'luck_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.730216374269
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.722529239766
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'AdjT_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.736707602339
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'AdjT_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.736657894737
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'AdjT_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.721035087719
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.70999122807
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'AdjD_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.747611111111
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'AdjD_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.746242690058
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.740192982456
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'AdjO_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.739979532164
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.713114035088
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'SOS_x-y'] w/ 5-fold CV : 0.71798245614
# Average confidence w/ 100 repetitions for  ['SOS_x-y'] w/ 5-fold CV : 0.714695906433
# Average confidence w/ 100 repetitions for  ['L_x-y', 'W_L_ratio_x-y', 'SRS_x-y'] w/ 5-fold CV : 0.702067251462
# Average confidence w/ 100 repetitions for  ['W_x-y', 'W_L_ratio_x-y', 'SRS_x-y'] w/ 5-fold CV : 0.744295321637
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'W_L_ratio_x-y', 'SRS_x-y'] w/ 5-fold CV : 0.72883625731
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'W_L_ratio_x-y', 'SRS_x-y'] w/ 5-fold CV : 0.696652046784
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'W_L_ratio_x-y', 'SRS_x-y'] w/ 5-fold CV : 0.729757309942
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'W_L_ratio_x-y', 'SRS_x-y'] w/ 5-fold CV : 0.71398245614
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'W_L_ratio_x-y', 'SRS_x-y'] w/ 5-fold CV : 0.723461988304
# Average confidence w/ 100 repetitions for  ['W_L_ratio_x-y', 'SRS_x-y'] w/ 5-fold CV : 0.72534502924
# Average confidence w/ 100 repetitions for  ['W_x-y', 'L_x-y', 'SRS_x-y'] w/ 5-fold CV : 0.767619883041
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'L_x-y', 'SRS_x-y'] w/ 5-fold CV : 0.701798245614
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'L_x-y', 'SRS_x-y'] w/ 5-fold CV : 0.742687134503
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'L_x-y', 'SRS_x-y'] w/ 5-fold CV : 0.740605263158
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'L_x-y', 'SRS_x-y'] w/ 5-fold CV : 0.726874269006
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'L_x-y', 'SRS_x-y'] w/ 5-fold CV : 0.70683625731
# Average confidence w/ 100 repetitions for  ['L_x-y', 'SRS_x-y'] w/ 5-fold CV : 0.696108187135
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'W_x-y', 'SRS_x-y'] w/ 5-fold CV : 0.744315789474
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'W_x-y', 'SRS_x-y'] w/ 5-fold CV : 0.758464912281
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'W_x-y', 'SRS_x-y'] w/ 5-fold CV : 0.753593567251
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'W_x-y', 'SRS_x-y'] w/ 5-fold CV : 0.746026315789
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'W_x-y', 'SRS_x-y'] w/ 5-fold CV : 0.72799122807
# Average confidence w/ 100 repetitions for  ['W_x-y', 'SRS_x-y'] w/ 5-fold CV : 0.724233918129
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'luck_x-y', 'SRS_x-y'] w/ 5-fold CV : 0.696134502924
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'luck_x-y', 'SRS_x-y'] w/ 5-fold CV : 0.728578947368
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'luck_x-y', 'SRS_x-y'] w/ 5-fold CV : 0.720567251462
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'luck_x-y', 'SRS_x-y'] w/ 5-fold CV : 0.725400584795
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'SRS_x-y'] w/ 5-fold CV : 0.725359649123
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'AdjT_x-y', 'SRS_x-y'] w/ 5-fold CV : 0.739763157895
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'AdjT_x-y', 'SRS_x-y'] w/ 5-fold CV : 0.729640350877
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'AdjT_x-y', 'SRS_x-y'] w/ 5-fold CV : 0.715470760234
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'SRS_x-y'] w/ 5-fold CV : 0.701985380117
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'AdjD_x-y', 'SRS_x-y'] w/ 5-fold CV : 0.750078947368
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'AdjD_x-y', 'SRS_x-y'] w/ 5-fold CV : 0.747997076023
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'SRS_x-y'] w/ 5-fold CV : 0.737149122807
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'AdjO_x-y', 'SRS_x-y'] w/ 5-fold CV : 0.746602339181
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'SRS_x-y'] w/ 5-fold CV : 0.711780701754
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'SRS_x-y'] w/ 5-fold CV : 0.713125730994
# Average confidence w/ 100 repetitions for  ['SRS_x-y'] w/ 5-fold CV : 0.720944444444
# Average confidence w/ 100 repetitions for  ['W_x-y', 'L_x-y', 'W_L_ratio_x-y'] w/ 5-fold CV : 0.790701754386
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'L_x-y', 'W_L_ratio_x-y'] w/ 5-fold CV : 0.740634502924
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'L_x-y', 'W_L_ratio_x-y'] w/ 5-fold CV : 0.737684210526
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'L_x-y', 'W_L_ratio_x-y'] w/ 5-fold CV : 0.727140350877
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'L_x-y', 'W_L_ratio_x-y'] w/ 5-fold CV : 0.731002923977
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'L_x-y', 'W_L_ratio_x-y'] w/ 5-fold CV : 0.725789473684
# Average confidence w/ 100 repetitions for  ['L_x-y', 'W_L_ratio_x-y'] w/ 5-fold CV : 0.735049707602
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'W_x-y', 'W_L_ratio_x-y'] w/ 5-fold CV : 0.770804093567
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'W_x-y', 'W_L_ratio_x-y'] w/ 5-fold CV : 0.791921052632
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'W_x-y', 'W_L_ratio_x-y'] w/ 5-fold CV : 0.746906432749
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'W_x-y', 'W_L_ratio_x-y'] w/ 5-fold CV : 0.753605263158
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'W_x-y', 'W_L_ratio_x-y'] w/ 5-fold CV : 0.762704678363
# Average confidence w/ 100 repetitions for  ['W_x-y', 'W_L_ratio_x-y'] w/ 5-fold CV : 0.765149122807
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'luck_x-y', 'W_L_ratio_x-y'] w/ 5-fold CV : 0.742780701754
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'luck_x-y', 'W_L_ratio_x-y'] w/ 5-fold CV : 0.728926900585
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'luck_x-y', 'W_L_ratio_x-y'] w/ 5-fold CV : 0.71766374269
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'luck_x-y', 'W_L_ratio_x-y'] w/ 5-fold CV : 0.762979532164
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'W_L_ratio_x-y'] w/ 5-fold CV : 0.743850877193
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'AdjT_x-y', 'W_L_ratio_x-y'] w/ 5-fold CV : 0.748058479532
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'AdjT_x-y', 'W_L_ratio_x-y'] w/ 5-fold CV : 0.718730994152
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'AdjT_x-y', 'W_L_ratio_x-y'] w/ 5-fold CV : 0.726640350877
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'W_L_ratio_x-y'] w/ 5-fold CV : 0.742485380117
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'AdjD_x-y', 'W_L_ratio_x-y'] w/ 5-fold CV : 0.736383040936
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'AdjD_x-y', 'W_L_ratio_x-y'] w/ 5-fold CV : 0.743538011696
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'W_L_ratio_x-y'] w/ 5-fold CV : 0.733488304094
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'AdjO_x-y', 'W_L_ratio_x-y'] w/ 5-fold CV : 0.740514619883
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'W_L_ratio_x-y'] w/ 5-fold CV : 0.719295321637
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'W_L_ratio_x-y'] w/ 5-fold CV : 0.758760233918
# Average confidence w/ 100 repetitions for  ['W_L_ratio_x-y'] w/ 5-fold CV : 0.74232748538
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'W_x-y', 'L_x-y'] w/ 5-fold CV : 0.785400584795
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'W_x-y', 'L_x-y'] w/ 5-fold CV : 0.768950292398
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'W_x-y', 'L_x-y'] w/ 5-fold CV : 0.772736842105
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'W_x-y', 'L_x-y'] w/ 5-fold CV : 0.770114035088
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'W_x-y', 'L_x-y'] w/ 5-fold CV : 0.760660818713
# Average confidence w/ 100 repetitions for  ['W_x-y', 'L_x-y'] w/ 5-fold CV : 0.774400584795
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'luck_x-y', 'L_x-y'] w/ 5-fold CV : 0.737543859649
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'luck_x-y', 'L_x-y'] w/ 5-fold CV : 0.736453216374
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'luck_x-y', 'L_x-y'] w/ 5-fold CV : 0.73598245614
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'luck_x-y', 'L_x-y'] w/ 5-fold CV : 0.726114035088
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'L_x-y'] w/ 5-fold CV : 0.740643274854
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'AdjT_x-y', 'L_x-y'] w/ 5-fold CV : 0.732304093567
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'AdjT_x-y', 'L_x-y'] w/ 5-fold CV : 0.753850877193
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'AdjT_x-y', 'L_x-y'] w/ 5-fold CV : 0.72719005848
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'L_x-y'] w/ 5-fold CV : 0.731459064327
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'AdjD_x-y', 'L_x-y'] w/ 5-fold CV : 0.729365497076
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'AdjD_x-y', 'L_x-y'] w/ 5-fold CV : 0.733160818713
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'L_x-y'] w/ 5-fold CV : 0.73114619883
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'AdjO_x-y', 'L_x-y'] w/ 5-fold CV : 0.732280701754
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'L_x-y'] w/ 5-fold CV : 0.745301169591
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'L_x-y'] w/ 5-fold CV : 0.718119883041
# Average confidence w/ 100 repetitions for  ['L_x-y'] w/ 5-fold CV : 0.732435672515
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'luck_x-y', 'W_x-y'] w/ 5-fold CV : 0.792005847953
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'luck_x-y', 'W_x-y'] w/ 5-fold CV : 0.749786549708
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'luck_x-y', 'W_x-y'] w/ 5-fold CV : 0.75833625731
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'luck_x-y', 'W_x-y'] w/ 5-fold CV : 0.762795321637
# Average confidence w/ 100 repetitions for  ['luck_x-y', 'W_x-y'] w/ 5-fold CV : 0.768786549708
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'AdjT_x-y', 'W_x-y'] w/ 5-fold CV : 0.743953216374
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'AdjT_x-y', 'W_x-y'] w/ 5-fold CV : 0.756426900585
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'AdjT_x-y', 'W_x-y'] w/ 5-fold CV : 0.753558479532
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'W_x-y'] w/ 5-fold CV : 0.783134502924
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'AdjD_x-y', 'W_x-y'] w/ 5-fold CV : 0.757283625731
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'AdjD_x-y', 'W_x-y'] w/ 5-fold CV : 0.756242690058
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'W_x-y'] w/ 5-fold CV : 0.743377192982
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'AdjO_x-y', 'W_x-y'] w/ 5-fold CV : 0.764877192982
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'W_x-y'] w/ 5-fold CV : 0.750365497076
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'W_x-y'] w/ 5-fold CV : 0.753964912281
# Average confidence w/ 100 repetitions for  ['W_x-y'] w/ 5-fold CV : 0.760005847953
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'AdjT_x-y', 'luck_x-y'] w/ 5-fold CV : 0.747494152047
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'AdjT_x-y', 'luck_x-y'] w/ 5-fold CV : 0.711763157895
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'AdjT_x-y', 'luck_x-y'] w/ 5-fold CV : 0.727245614035
# Average confidence w/ 100 repetitions for  ['AdjT_x-y', 'luck_x-y'] w/ 5-fold CV : 0.741269005848
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'AdjD_x-y', 'luck_x-y'] w/ 5-fold CV : 0.734561403509
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'AdjD_x-y', 'luck_x-y'] w/ 5-fold CV : 0.733824561404
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'luck_x-y'] w/ 5-fold CV : 0.735456140351
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'AdjO_x-y', 'luck_x-y'] w/ 5-fold CV : 0.73735380117
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'luck_x-y'] w/ 5-fold CV : 0.716160818713
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'luck_x-y'] w/ 5-fold CV : 0.754652046784
# Average confidence w/ 100 repetitions for  ['luck_x-y'] w/ 5-fold CV : 0.741271929825
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'AdjD_x-y', 'AdjT_x-y'] w/ 5-fold CV : 0.746692982456
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'AdjD_x-y', 'AdjT_x-y'] w/ 5-fold CV : 0.760137426901
# Average confidence w/ 100 repetitions for  ['AdjD_x-y', 'AdjT_x-y'] w/ 5-fold CV : 0.741631578947
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'AdjO_x-y', 'AdjT_x-y'] w/ 5-fold CV : 0.764964912281
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'AdjT_x-y'] w/ 5-fold CV : 0.714114035088
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'AdjT_x-y'] w/ 5-fold CV : 0.732959064327
# Average confidence w/ 100 repetitions for  ['AdjT_x-y'] w/ 5-fold CV : 0.744239766082
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'AdjO_x-y', 'AdjD_x-y'] w/ 5-fold CV : 0.738891812865
# Average confidence w/ 100 repetitions for  ['AdjO_x-y', 'AdjD_x-y'] w/ 5-fold CV : 0.740643274854
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'AdjD_x-y'] w/ 5-fold CV : 0.736076023392
# Average confidence w/ 100 repetitions for  ['AdjD_x-y'] w/ 5-fold CV : 0.746652046784
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y', 'AdjO_x-y'] w/ 5-fold CV : 0.737166666667
# Average confidence w/ 100 repetitions for  ['AdjO_x-y'] w/ 5-fold CV : 0.714660818713
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y'] w/ 5-fold CV : 0.74081871345

# %%
sorted(feature_r_squared, key=feature_r_squared.get, reverse=True)
# Out:
# ["['AdjT_x-y', 'W_x-y', 'PT_Ratio_x-y']",
#  "['AdjT_x-y', 'W_x-y', 'True_S_x-y']",
#  "['AdjT_x-y', 'luck_x-y', 'W_x-y']",
#  "['AdjT_x-y', 'W_x-y', 'W_L_ratio_x-y']",
#  "['W_x-y', 'L_x-y', 'W_L_ratio_x-y']",
#  "['W_x-y', 'L_x-y', 'True_S_x-y']",
#  "['W_x-y', 'L_x-y', 'PT_Ratio_x-y']",
#  "['luck_x-y', 'W_x-y', 'L_x-y']",
#  "['luck_x-y', 'W_x-y', 'SOS_x-y']",
#  "['AdjT_x-y', 'W_x-y']",
#  "['W_x-y', 'W_L_ratio_x-y', 'SOS_x-y']",
#  "['W_x-y', 'SOS_x-y', 'True_S_x-y']",
#  "['W_x-y', 'L_x-y', 'SOS_x-y']",
#  "['W_x-y', 'SOS_x-y', 'PT_Ratio_x-y']",
#  "['W_x-y', 'SOS_x-y', 'seed_x-y']",
#  "['W_x-y', 'L_x-y']",
#  "['W_x-y', 'W_L_ratio_x-y', 'True_S_x-y']",
#  "['AdjD_x-y', 'W_x-y', 'L_x-y']",
#  "['W_x-y', 'L_x-y', 'seed_x-y']",
#  "['AdjT_x-y', 'W_x-y', 'seed_x-y']",
#  "['luck_x-y', 'W_x-y', 'W_L_ratio_x-y']",
#  "['AdjO_x-y', 'W_x-y', 'L_x-y']",
#  "['luck_x-y', 'W_x-y', 'PT_Ratio_x-y']",
#  "['AdjT_x-y', 'W_x-y', 'L_x-y']",
#  "['luck_x-y', 'W_x-y']",
#  "['W_x-y', 'PT_Ratio_x-y', 'True_S_x-y']",
#  "['W_x-y', 'L_x-y', 'SRS_x-y']",
#  "['AdjO_x-y', 'W_x-y', 'seed_x-y']",
#  "['W_x-y', 'True_S_x-y', 'seed_x-y']",
#  "['W_x-y', 'SOS_x-y']",
#  "['W_x-y', 'W_L_ratio_x-y', 'PT_Ratio_x-y']",
#  "['W_x-y', 'W_L_ratio_x-y', 'seed_x-y']",
#  "['W_x-y', 'PT_Ratio_x-y']",
#  "['AdjT_x-y', 'W_x-y', 'SOS_x-y']",
#  "['luck_x-y', 'W_x-y', 'True_S_x-y']",
#  "['AdjEM_x-y', 'W_x-y', 'PT_Ratio_x-y']",
#  "['W_x-y', 'W_L_ratio_x-y']",
#  "['W_x-y', 'True_S_x-y']",
#  "['W_x-y', 'PT_Ratio_x-y', 'seed_x-y']",
#  "['AdjEM_x-y', 'AdjO_x-y', 'AdjT_x-y']",
#  "['AdjEM_x-y', 'AdjO_x-y', 'W_x-y']",
#  "['luck_x-y', 'W_x-y', 'seed_x-y']",
#  "['AdjEM_x-y', 'luck_x-y', 'W_L_ratio_x-y']",
#  "['AdjEM_x-y', 'PT_Ratio_x-y', 'True_S_x-y']",
#  "['AdjEM_x-y', 'luck_x-y', 'W_x-y']",
#  "['AdjEM_x-y', 'W_x-y', 'W_L_ratio_x-y']",
#  "['AdjEM_x-y', 'W_L_ratio_x-y', 'True_S_x-y']",
#  "['AdjEM_x-y', 'W_x-y', 'True_S_x-y']",
#  "['AdjEM_x-y', 'luck_x-y', 'True_S_x-y']",
#  "['AdjEM_x-y', 'SOS_x-y', 'seed_x-y']",
#  "['AdjD_x-y', 'W_x-y', 'SOS_x-y']",
#  "['AdjEM_x-y', 'luck_x-y', 'PT_Ratio_x-y']",
#  "['AdjEM_x-y', 'W_L_ratio_x-y', 'PT_Ratio_x-y']",
#  "['AdjEM_x-y', 'W_x-y', 'L_x-y']",
#  "['AdjEM_x-y', 'AdjD_x-y', 'AdjT_x-y']",
#  "['W_x-y']",
#  "['AdjEM_x-y', 'W_x-y', 'seed_x-y']",
#  "['AdjEM_x-y', 'W_L_ratio_x-y']",
#  "['AdjEM_x-y', 'PT_Ratio_x-y']",
#  "['AdjT_x-y', 'W_x-y', 'SRS_x-y']",
#  "['AdjO_x-y', 'luck_x-y', 'W_x-y']",
#  "['AdjO_x-y', 'W_x-y', 'True_S_x-y']",
#  "['AdjO_x-y', 'AdjD_x-y', 'W_x-y']",
#  "['AdjEM_x-y', 'True_S_x-y']",
#  "['AdjO_x-y', 'AdjT_x-y', 'W_x-y']",
#  "['AdjEM_x-y', 'AdjD_x-y', 'W_x-y']",
#  "['AdjD_x-y', 'L_x-y', 'SOS_x-y']",
#  "['SRS_x-y', 'SOS_x-y', 'seed_x-y']",
#  "['AdjO_x-y', 'W_x-y', 'PT_Ratio_x-y']",
#  "['AdjEM_x-y', 'luck_x-y']",
#  "['W_x-y', 'seed_x-y']",
#  "['AdjEM_x-y', 'W_x-y']",
#  "['AdjO_x-y', 'AdjT_x-y', 'L_x-y']",
#  "['AdjO_x-y', 'W_x-y', 'W_L_ratio_x-y']",
#  "['AdjD_x-y', 'W_x-y', 'SRS_x-y']",
#  "['AdjEM_x-y', 'AdjT_x-y', 'W_x-y']",
#  "['SOS_x-y', 'TM_pt_x-y']",
#  "['AdjD_x-y', 'SOS_x-y', 'seed_x-y']",
#  "['AdjD_x-y', 'W_x-y', 'TM_pt_x-y']",
#  "['SOS_x-y', 'TM_pt_x-y', 'PT_Ratio_x-y']",
#  "['W_x-y', 'SRS_x-y', 'SOS_x-y']",
#  "['AdjO_x-y', 'L_x-y', 'OPPO_pt_x-y']",
#  "['SOS_x-y', 'TM_pt_x-y', 'True_S_x-y']",
#  "['AdjO_x-y', 'W_x-y']",
#  "['AdjO_x-y', 'AdjD_x-y', 'SRS_x-y']",
#  "['luck_x-y', 'SOS_x-y', 'TM_pt_x-y']",
#  "['AdjD_x-y', 'luck_x-y', 'W_x-y']",
#  "['AdjD_x-y', 'AdjT_x-y', 'True_S_x-y']",
#  "['AdjD_x-y', 'L_x-y', 'seed_x-y']",
#  "['AdjD_x-y', 'TM_pt_x-y', 'PT_Ratio_x-y']",
#  "['AdjD_x-y', 'AdjT_x-y', 'PT_Ratio_x-y']",
#  "['AdjD_x-y', 'W_x-y', 'PT_Ratio_x-y']",
#  "['W_L_ratio_x-y', 'SOS_x-y', 'TM_pt_x-y']",
#  "['AdjEM_x-y', 'L_x-y', 'SOS_x-y']",
#  "['AdjD_x-y', 'AdjT_x-y', 'W_L_ratio_x-y']",
#  "['AdjD_x-y', 'W_x-y', 'True_S_x-y']",
#  "['AdjEM_x-y', 'AdjD_x-y', 'SRS_x-y']",
#  "['L_x-y', 'W_L_ratio_x-y', 'SOS_x-y']",
#  "['AdjO_x-y', 'AdjD_x-y', 'SOS_x-y']",
#  "['AdjD_x-y', 'AdjT_x-y', 'luck_x-y']",
#  "['AdjEM_x-y', 'AdjD_x-y', 'seed_x-y']",
#  "['AdjO_x-y', 'luck_x-y', 'OPPO_pt_x-y']",
#  "['AdjD_x-y', 'TM_pt_x-y', 'True_S_x-y']",
#  "['AdjD_x-y', 'W_x-y', 'W_L_ratio_x-y']",
#  "['AdjD_x-y', 'luck_x-y', 'TM_pt_x-y']",
#  "['luck_x-y', 'W_x-y', 'TM_pt_x-y']",
#  "['AdjT_x-y', 'luck_x-y', 'True_S_x-y']",
#  "['AdjO_x-y', 'AdjD_x-y', 'AdjT_x-y']",
#  "['AdjD_x-y']",
#  "['AdjEM_x-y', 'AdjO_x-y', 'SRS_x-y']",
#  "['AdjO_x-y', 'W_L_ratio_x-y', 'OPPO_pt_x-y']",
#  "['AdjT_x-y', 'OPPO_pt_x-y', 'True_S_x-y']",
#  "['AdjEM_x-y', 'AdjD_x-y', 'SOS_x-y']",
#  "['W_x-y', 'TM_pt_x-y', 'PT_Ratio_x-y']",
#  "['AdjEM_x-y', 'TM_pt_x-y', 'seed_x-y']",
#  "['AdjO_x-y', 'W_x-y', 'SRS_x-y']",
#  "['SRS_x-y', 'TM_pt_x-y', 'PT_Ratio_x-y']",
#  "['AdjT_x-y', 'W_L_ratio_x-y', 'OPPO_pt_x-y']",
#  "['W_x-y', 'SRS_x-y', 'True_S_x-y']",
#  "['L_x-y', 'SOS_x-y', 'seed_x-y']",
#  "['W_x-y', 'OPPO_pt_x-y', 'seed_x-y']",
#  "['AdjD_x-y', 'L_x-y', 'OPPO_pt_x-y']",
#  "['TM_pt_x-y', 'OPPO_pt_x-y', 'seed_x-y']",
#  "['AdjT_x-y', 'L_x-y', 'TM_pt_x-y']",
#  "['AdjT_x-y', 'SOS_x-y', 'TM_pt_x-y']",
#  "['AdjO_x-y', 'L_x-y']",
#  "['AdjO_x-y', 'OPPO_pt_x-y', 'PT_Ratio_x-y']",
#  "['True_S_x-y']",
#  "['AdjEM_x-y', 'AdjT_x-y', 'TM_pt_x-y']",
#  "['W_x-y', 'TM_pt_x-y', 'True_S_x-y']",
#  "['AdjT_x-y', 'TM_pt_x-y', 'OPPO_pt_x-y']",
#  "['AdjEM_x-y', 'SOS_x-y', 'TM_pt_x-y']",
#  "['TM_pt_x-y', 'OPPO_pt_x-y', 'PT_Ratio_x-y']",
#  "['SOS_x-y', 'TM_pt_x-y', 'OPPO_pt_x-y']",
#  "['AdjD_x-y', 'W_L_ratio_x-y', 'OPPO_pt_x-y']",
#  "['W_L_ratio_x-y', 'PT_Ratio_x-y']",
#  "['W_x-y', 'W_L_ratio_x-y', 'TM_pt_x-y']",
#  "['luck_x-y', 'W_L_ratio_x-y', 'True_S_x-y']",
#  "['AdjO_x-y', 'SOS_x-y', 'OPPO_pt_x-y']",
#  "['AdjO_x-y', 'OPPO_pt_x-y', 'seed_x-y']",
#  "['W_x-y', 'TM_pt_x-y']",
#  "['AdjD_x-y', 'W_x-y', 'OPPO_pt_x-y']",
#  "['AdjO_x-y', 'OPPO_pt_x-y']",
#  "['AdjEM_x-y', 'SRS_x-y', 'TM_pt_x-y']",
#  "['AdjD_x-y', 'SRS_x-y', 'SOS_x-y']",
#  "['luck_x-y', 'W_x-y', 'SRS_x-y']",
#  "['AdjT_x-y', 'luck_x-y', 'PT_Ratio_x-y']",
#  "['W_x-y', 'W_L_ratio_x-y', 'SRS_x-y']",
#  "['AdjEM_x-y', 'L_x-y', 'OPPO_pt_x-y']",
#  "['luck_x-y', 'SRS_x-y', 'TM_pt_x-y']",
#  "['AdjT_x-y']",
#  "['AdjT_x-y', 'SRS_x-y', 'OPPO_pt_x-y']",
#  "['SRS_x-y', 'TM_pt_x-y']",
#  "['AdjT_x-y', 'PT_Ratio_x-y']",
#  "['AdjEM_x-y', 'TM_pt_x-y', 'OPPO_pt_x-y']",
#  "['AdjD_x-y', 'TM_pt_x-y', 'OPPO_pt_x-y']",
#  "['AdjT_x-y', 'W_x-y', 'TM_pt_x-y']",
#  "['SRS_x-y', 'SOS_x-y', 'OPPO_pt_x-y']",
#  "['L_x-y', 'SOS_x-y', 'PT_Ratio_x-y']",
#  "['W_x-y', 'TM_pt_x-y', 'OPPO_pt_x-y']",
#  "['AdjO_x-y', 'SRS_x-y', 'TM_pt_x-y']",
#  "['AdjD_x-y', 'TM_pt_x-y', 'seed_x-y']",
#  "['TM_pt_x-y', 'OPPO_pt_x-y', 'True_S_x-y']",
#  "['AdjD_x-y', 'AdjT_x-y', 'W_x-y']",
#  "['AdjO_x-y', 'AdjD_x-y', 'OPPO_pt_x-y']",
#  "['AdjT_x-y', 'OPPO_pt_x-y', 'PT_Ratio_x-y']",
#  "['AdjD_x-y', 'W_L_ratio_x-y', 'TM_pt_x-y']",
#  "['AdjD_x-y', 'SOS_x-y', 'OPPO_pt_x-y']",
#  "['AdjO_x-y', 'OPPO_pt_x-y', 'True_S_x-y']",
#  "['luck_x-y', 'W_L_ratio_x-y']",
#  "['luck_x-y', 'PT_Ratio_x-y']",
#  "['L_x-y', 'SOS_x-y', 'OPPO_pt_x-y']",
#  "['AdjEM_x-y', 'AdjO_x-y', 'TM_pt_x-y']",
#  "['AdjO_x-y', 'AdjD_x-y', 'seed_x-y']",
#  "['AdjD_x-y', 'luck_x-y', 'SOS_x-y']",
#  "['AdjO_x-y', 'W_x-y', 'OPPO_pt_x-y']",
#  "['AdjT_x-y', 'W_x-y', 'OPPO_pt_x-y']",
#  "['AdjD_x-y', 'OPPO_pt_x-y', 'seed_x-y']",
#  "['luck_x-y', 'PT_Ratio_x-y', 'True_S_x-y']",
#  "['AdjO_x-y', 'AdjT_x-y', 'OPPO_pt_x-y']",
#  "['SRS_x-y', 'OPPO_pt_x-y', 'seed_x-y']",
#  "['AdjEM_x-y', 'W_x-y', 'OPPO_pt_x-y']",
#  "['W_x-y', 'SRS_x-y', 'OPPO_pt_x-y']",
#  "['AdjEM_x-y', 'AdjD_x-y', 'W_L_ratio_x-y']",
#  "['AdjT_x-y', 'SRS_x-y', 'TM_pt_x-y']",
#  "['AdjO_x-y', 'SOS_x-y', 'TM_pt_x-y']",
#  "['L_x-y', 'OPPO_pt_x-y', 'seed_x-y']",
#  "['AdjT_x-y', 'PT_Ratio_x-y', 'True_S_x-y']",
#  "['AdjO_x-y', 'SRS_x-y', 'OPPO_pt_x-y']",
#  "['AdjD_x-y', 'W_x-y']",
#  "['AdjT_x-y', 'L_x-y', 'OPPO_pt_x-y']",
#  "['AdjEM_x-y', 'AdjD_x-y', 'True_S_x-y']",
#  "['SRS_x-y', 'TM_pt_x-y', 'seed_x-y']",
#  "['SOS_x-y', 'OPPO_pt_x-y', 'seed_x-y']",
#  "['W_L_ratio_x-y', 'TM_pt_x-y', 'OPPO_pt_x-y']",
#  "['AdjEM_x-y', 'W_x-y', 'TM_pt_x-y']",
#  "['W_L_ratio_x-y', 'True_S_x-y']",
#  "['luck_x-y', 'W_L_ratio_x-y', 'PT_Ratio_x-y']",
#  "['AdjD_x-y', 'AdjT_x-y', 'TM_pt_x-y']",
#  "['L_x-y', 'SRS_x-y', 'OPPO_pt_x-y']",
#  "['SRS_x-y', 'SOS_x-y', 'TM_pt_x-y']",
#  "['TM_pt_x-y', 'OPPO_pt_x-y']",
#  "['AdjT_x-y', 'TM_pt_x-y', 'seed_x-y']",
#  "['AdjO_x-y', 'AdjD_x-y', 'TM_pt_x-y']",
#  "['PT_Ratio_x-y']",
#  "['AdjEM_x-y', 'SOS_x-y', 'OPPO_pt_x-y']",
#  "['luck_x-y', 'True_S_x-y']",
#  "['SOS_x-y', 'TM_pt_x-y', 'seed_x-y']",
#  "['AdjO_x-y', 'TM_pt_x-y', 'seed_x-y']",
#  "['AdjD_x-y', 'AdjT_x-y', 'OPPO_pt_x-y']",
#  "['W_L_ratio_x-y', 'SRS_x-y', 'TM_pt_x-y']",
#  "['PT_Ratio_x-y', 'True_S_x-y']",
#  "['AdjEM_x-y', 'AdjO_x-y', 'OPPO_pt_x-y']",
#  "['AdjT_x-y', 'luck_x-y', 'OPPO_pt_x-y']",
#  "['AdjEM_x-y', 'AdjD_x-y', 'OPPO_pt_x-y']",
#  "['AdjT_x-y', 'luck_x-y', 'W_L_ratio_x-y']",
#  "['AdjT_x-y', 'L_x-y', 'SRS_x-y']",
#  "['AdjT_x-y', 'W_L_ratio_x-y', 'PT_Ratio_x-y']",
#  "['AdjD_x-y', 'L_x-y', 'TM_pt_x-y']",
#  "['AdjT_x-y', 'TM_pt_x-y']",
#  "['W_x-y', 'W_L_ratio_x-y', 'OPPO_pt_x-y']",
#  "['AdjEM_x-y', 'AdjD_x-y', 'TM_pt_x-y']",
#  "['L_x-y', 'SOS_x-y', 'TM_pt_x-y']",
#  "['AdjD_x-y', 'TM_pt_x-y']",
#  "['AdjEM_x-y', 'AdjO_x-y', 'True_S_x-y']",
#  "['SOS_x-y', 'OPPO_pt_x-y']",
#  "['AdjT_x-y', 'W_L_ratio_x-y']",
#  "['W_x-y', 'TM_pt_x-y', 'seed_x-y']",
#  "['SRS_x-y', 'TM_pt_x-y', 'True_S_x-y']",
#  "['AdjT_x-y', 'SOS_x-y', 'OPPO_pt_x-y']",
#  "['L_x-y', 'TM_pt_x-y', 'OPPO_pt_x-y']",
#  "['W_L_ratio_x-y']",
#  "['TM_pt_x-y', 'seed_x-y']",
#  "['luck_x-y', 'L_x-y', 'True_S_x-y']",
#  "['AdjT_x-y', 'W_L_ratio_x-y', 'True_S_x-y']",
#  "['AdjT_x-y', 'True_S_x-y']",
#  "['luck_x-y', 'TM_pt_x-y', 'OPPO_pt_x-y']",
#  "['AdjEM_x-y', 'AdjT_x-y', 'OPPO_pt_x-y']",
#  "['AdjD_x-y', 'luck_x-y', 'OPPO_pt_x-y']",
#  "['AdjEM_x-y', 'W_x-y', 'SOS_x-y']",
#  "['W_x-y', 'SOS_x-y', 'OPPO_pt_x-y']",
#  "['AdjEM_x-y', 'AdjO_x-y', 'PT_Ratio_x-y']",
#  "['AdjEM_x-y', 'TM_pt_x-y', 'True_S_x-y']",
#  "['AdjO_x-y', 'TM_pt_x-y', 'OPPO_pt_x-y']",
#  "['W_L_ratio_x-y', 'SOS_x-y', 'seed_x-y']",
#  "['AdjD_x-y', 'SRS_x-y', 'OPPO_pt_x-y']",
#  "['W_x-y', 'OPPO_pt_x-y']",
#  "['luck_x-y', 'L_x-y', 'TM_pt_x-y']",
#  "['AdjD_x-y', 'AdjT_x-y']",
#  "['AdjEM_x-y', 'TM_pt_x-y']",
#  "['AdjEM_x-y', 'SRS_x-y', 'OPPO_pt_x-y']",
#  "['AdjD_x-y', 'OPPO_pt_x-y', 'True_S_x-y']",
#  "['AdjD_x-y', 'SRS_x-y', 'TM_pt_x-y']",
#  "['AdjT_x-y', 'OPPO_pt_x-y', 'seed_x-y']",
#  "['W_x-y', 'SOS_x-y', 'TM_pt_x-y']",
#  "['L_x-y', 'TM_pt_x-y', 'seed_x-y']",
#  "['L_x-y', 'PT_Ratio_x-y', 'True_S_x-y']",
#  "['AdjO_x-y', 'L_x-y', 'TM_pt_x-y']",
#  "['luck_x-y']",
#  "['W_L_ratio_x-y', 'SRS_x-y', 'seed_x-y']",
#  "['AdjT_x-y', 'luck_x-y']",
#  "['L_x-y', 'SRS_x-y', 'TM_pt_x-y']",
#  "['W_L_ratio_x-y', 'PT_Ratio_x-y', 'True_S_x-y']",
#  "['AdjT_x-y', 'L_x-y', 'True_S_x-y']",
#  "['luck_x-y', 'L_x-y', 'SOS_x-y']",
#  "['L_x-y', 'SOS_x-y', 'True_S_x-y']",
#  "['AdjT_x-y', 'OPPO_pt_x-y']",
#  "['SOS_x-y', 'OPPO_pt_x-y', 'True_S_x-y']",
#  "['AdjD_x-y', 'OPPO_pt_x-y', 'PT_Ratio_x-y']",
#  "['AdjEM_x-y']",
#  "['W_x-y', 'SRS_x-y', 'PT_Ratio_x-y']",
#  "['L_x-y', 'OPPO_pt_x-y']",
#  "['L_x-y', 'TM_pt_x-y']",
#  "['SRS_x-y', 'TM_pt_x-y', 'OPPO_pt_x-y']",
#  "['luck_x-y', 'L_x-y']",
#  "['AdjO_x-y', 'AdjD_x-y']",
#  "['luck_x-y', 'L_x-y', 'W_L_ratio_x-y']",
#  "['AdjD_x-y', 'L_x-y', 'SRS_x-y']",
#  "['W_x-y', 'SRS_x-y', 'TM_pt_x-y']",
#  "['AdjEM_x-y', 'AdjO_x-y', 'W_L_ratio_x-y']",
#  "['AdjO_x-y', 'AdjT_x-y', 'TM_pt_x-y']",
#  "['AdjD_x-y', 'W_L_ratio_x-y', 'SOS_x-y']",
#  "['L_x-y', 'OPPO_pt_x-y', 'PT_Ratio_x-y']",
#  "['SOS_x-y', 'OPPO_pt_x-y', 'PT_Ratio_x-y']",
#  "['luck_x-y', 'TM_pt_x-y', 'seed_x-y']",
#  "['AdjEM_x-y', 'seed_x-y']",
#  "['AdjD_x-y', 'SOS_x-y']",
#  "['L_x-y', 'W_L_ratio_x-y', 'True_S_x-y']",
#  "['W_x-y', 'L_x-y', 'TM_pt_x-y']",
#  "['AdjEM_x-y', 'luck_x-y', 'TM_pt_x-y']",
#  "['L_x-y', 'W_L_ratio_x-y', 'PT_Ratio_x-y']",
#  "['AdjD_x-y', 'SOS_x-y', 'TM_pt_x-y']",
#  "['AdjEM_x-y', 'OPPO_pt_x-y']",
#  "['L_x-y', 'TM_pt_x-y', 'True_S_x-y']",
#  "['AdjD_x-y', 'SOS_x-y', 'True_S_x-y']",
#  "['AdjEM_x-y', 'TM_pt_x-y', 'PT_Ratio_x-y']",
#  "['W_x-y', 'L_x-y', 'OPPO_pt_x-y']",
#  "['luck_x-y', 'L_x-y', 'PT_Ratio_x-y']",
#  "['AdjEM_x-y', 'AdjO_x-y', 'SOS_x-y']",
#  "['AdjEM_x-y', 'W_L_ratio_x-y', 'seed_x-y']",
#  "['W_L_ratio_x-y', 'TM_pt_x-y', 'seed_x-y']",
#  "['W_L_ratio_x-y', 'SOS_x-y', 'OPPO_pt_x-y']",
#  "['AdjEM_x-y', 'W_L_ratio_x-y', 'TM_pt_x-y']",
#  "['AdjD_x-y', 'AdjT_x-y', 'SRS_x-y']",
#  "['L_x-y', 'OPPO_pt_x-y', 'True_S_x-y']",
#  "['AdjEM_x-y', 'True_S_x-y', 'seed_x-y']",
#  "['SRS_x-y', 'PT_Ratio_x-y', 'seed_x-y']",
#  "['TM_pt_x-y', 'PT_Ratio_x-y', 'seed_x-y']",
#  "['L_x-y', 'TM_pt_x-y', 'PT_Ratio_x-y']",
#  "['luck_x-y', 'L_x-y', 'OPPO_pt_x-y']",
#  "['luck_x-y', 'SRS_x-y', 'seed_x-y']",
#  "['W_x-y', 'OPPO_pt_x-y', 'True_S_x-y']",
#  "['AdjD_x-y', 'PT_Ratio_x-y']",
#  "['AdjO_x-y', 'W_x-y', 'TM_pt_x-y']",
#  "['AdjD_x-y', 'SOS_x-y', 'PT_Ratio_x-y']",
#  "['AdjEM_x-y', 'AdjO_x-y', 'AdjD_x-y']",
#  "['SRS_x-y', 'True_S_x-y', 'seed_x-y']",
#  "['W_x-y', 'OPPO_pt_x-y', 'PT_Ratio_x-y']",
#  "['luck_x-y', 'W_x-y', 'OPPO_pt_x-y']",
#  "['SRS_x-y', 'OPPO_pt_x-y']",
#  "['AdjEM_x-y', 'L_x-y', 'TM_pt_x-y']",
#  "['AdjEM_x-y', 'OPPO_pt_x-y', 'seed_x-y']",
#  "['AdjEM_x-y', 'OPPO_pt_x-y', 'PT_Ratio_x-y']",
#  "['SOS_x-y', 'seed_x-y']",
#  "['TM_pt_x-y', 'True_S_x-y', 'seed_x-y']",
#  "['W_x-y', 'SRS_x-y', 'seed_x-y']",
#  "['L_x-y', 'W_L_ratio_x-y', 'TM_pt_x-y']",
#  "['AdjEM_x-y', 'W_L_ratio_x-y', 'OPPO_pt_x-y']",
#  "['SRS_x-y', 'seed_x-y']",
#  "['L_x-y', 'PT_Ratio_x-y']",
#  "['AdjEM_x-y', 'PT_Ratio_x-y', 'seed_x-y']",
#  "['AdjO_x-y', 'SOS_x-y', 'seed_x-y']",
#  "['AdjD_x-y', 'L_x-y', 'PT_Ratio_x-y']",
#  "['luck_x-y', 'SOS_x-y', 'OPPO_pt_x-y']",
#  "['L_x-y', 'W_L_ratio_x-y', 'OPPO_pt_x-y']",
#  "['AdjEM_x-y', 'SRS_x-y', 'SOS_x-y']",
#  "['AdjEM_x-y', 'OPPO_pt_x-y', 'True_S_x-y']",
#  "['AdjO_x-y', 'L_x-y', 'True_S_x-y']",
#  "['AdjT_x-y', 'L_x-y', 'W_L_ratio_x-y']",
#  "['L_x-y', 'SRS_x-y', 'SOS_x-y']",
#  "['AdjEM_x-y', 'luck_x-y', 'OPPO_pt_x-y']",
#  "['AdjT_x-y', 'luck_x-y', 'L_x-y']",
#  "['AdjD_x-y', 'W_x-y', 'seed_x-y']",
#  "['AdjEM_x-y', 'AdjO_x-y', 'luck_x-y']",
#  "['AdjD_x-y', 'SRS_x-y', 'seed_x-y']",
#  "['AdjEM_x-y', 'AdjO_x-y']",
#  "['AdjD_x-y', 'SRS_x-y']",
#  "['L_x-y', 'SOS_x-y']",
#  "['L_x-y', 'True_S_x-y']",
#  "['SRS_x-y', 'OPPO_pt_x-y', 'PT_Ratio_x-y']",
#  "['AdjD_x-y', 'OPPO_pt_x-y']",
#  "['AdjT_x-y', 'L_x-y', 'PT_Ratio_x-y']",
#  "['AdjD_x-y', 'AdjT_x-y', 'SOS_x-y']",
#  "['AdjO_x-y', 'AdjT_x-y', 'SOS_x-y']",
#  "['OPPO_pt_x-y', 'seed_x-y']",
#  "['SOS_x-y', 'True_S_x-y', 'seed_x-y']",
#  "['SOS_x-y', 'PT_Ratio_x-y', 'seed_x-y']",
#  "['AdjD_x-y', 'luck_x-y', 'L_x-y']",
#  "['AdjO_x-y', 'AdjD_x-y', 'W_L_ratio_x-y']",
#  "['luck_x-y', 'SOS_x-y', 'seed_x-y']",
#  "['AdjT_x-y', 'L_x-y', 'SOS_x-y']",
#  "['AdjEM_x-y', 'luck_x-y', 'seed_x-y']",
#  "['AdjT_x-y', 'W_L_ratio_x-y', 'TM_pt_x-y']",
#  "['AdjD_x-y', 'True_S_x-y']",
#  "['AdjD_x-y', 'L_x-y', 'True_S_x-y']",
#  "['AdjEM_x-y', 'AdjD_x-y']",
#  "['AdjO_x-y', 'luck_x-y', 'L_x-y']",
#  "['OPPO_pt_x-y', 'PT_Ratio_x-y', 'seed_x-y']",
#  "['AdjO_x-y', 'TM_pt_x-y']",
#  "['AdjO_x-y', 'W_L_ratio_x-y', 'TM_pt_x-y']",
#  "['AdjO_x-y', 'luck_x-y', 'TM_pt_x-y']",
#  "['AdjD_x-y', 'luck_x-y']",
#  "['luck_x-y', 'SRS_x-y', 'OPPO_pt_x-y']",
#  "['L_x-y', 'W_L_ratio_x-y']",
#  "['SRS_x-y', 'OPPO_pt_x-y', 'True_S_x-y']",
#  "['AdjO_x-y', 'AdjD_x-y', 'luck_x-y']",
#  "['AdjO_x-y', 'L_x-y', 'PT_Ratio_x-y']",
#  "['AdjT_x-y', 'luck_x-y', 'TM_pt_x-y']",
#  "['AdjO_x-y', 'AdjD_x-y', 'PT_Ratio_x-y']",
#  "['AdjO_x-y', 'L_x-y', 'SOS_x-y']",
#  "['AdjEM_x-y', 'AdjD_x-y', 'luck_x-y']",
#  "['W_L_ratio_x-y', 'SRS_x-y', 'PT_Ratio_x-y']",
#  "['L_x-y', 'SRS_x-y', 'seed_x-y']",
#  "['AdjD_x-y', 'W_L_ratio_x-y']",
#  "['OPPO_pt_x-y', 'True_S_x-y', 'seed_x-y']",
#  "['AdjT_x-y', 'TM_pt_x-y', 'True_S_x-y']",
#  "['AdjEM_x-y', 'AdjD_x-y', 'L_x-y']",
#  "['AdjEM_x-y', 'AdjT_x-y']",
#  "['AdjT_x-y', 'TM_pt_x-y', 'PT_Ratio_x-y']",
#  "['AdjEM_x-y', 'SRS_x-y', 'seed_x-y']",
#  "['AdjO_x-y', 'TM_pt_x-y', 'PT_Ratio_x-y']",
#  "['luck_x-y', 'OPPO_pt_x-y', 'seed_x-y']",
#  "['AdjEM_x-y', 'AdjD_x-y', 'PT_Ratio_x-y']",
#  "['L_x-y']",
#  "['SRS_x-y', 'PT_Ratio_x-y', 'True_S_x-y']",
#  "['AdjO_x-y', 'AdjD_x-y', 'True_S_x-y']",
#  "['AdjD_x-y', 'AdjT_x-y', 'L_x-y']",
#  "['W_L_ratio_x-y', 'SRS_x-y', 'OPPO_pt_x-y']",
#  "['W_L_ratio_x-y', 'SRS_x-y', 'SOS_x-y']",
#  "['AdjEM_x-y', 'AdjO_x-y', 'L_x-y']",
#  "['AdjT_x-y', 'L_x-y']",
#  "['AdjD_x-y', 'L_x-y']",
#  "['AdjD_x-y', 'SRS_x-y', 'True_S_x-y']",
#  "['AdjO_x-y', 'L_x-y', 'W_L_ratio_x-y']",
#  "['AdjO_x-y', 'TM_pt_x-y', 'True_S_x-y']",
#  "['W_L_ratio_x-y', 'OPPO_pt_x-y', 'seed_x-y']",
#  "['AdjD_x-y', 'W_L_ratio_x-y', 'True_S_x-y']",
#  "['AdjEM_x-y', 'AdjT_x-y', 'True_S_x-y']",
#  "['AdjO_x-y', 'L_x-y', 'seed_x-y']",
#  "['AdjO_x-y', 'W_x-y', 'SOS_x-y']",
#  "['AdjEM_x-y', 'luck_x-y', 'SOS_x-y']",
#  "['AdjEM_x-y', 'AdjO_x-y', 'seed_x-y']",
#  "['luck_x-y', 'SOS_x-y', 'True_S_x-y']",
#  "['AdjD_x-y', 'PT_Ratio_x-y', 'True_S_x-y']",
#  "['luck_x-y', 'W_L_ratio_x-y', 'SOS_x-y']",
#  "['AdjD_x-y', 'W_L_ratio_x-y', 'SRS_x-y']",
#  "['AdjO_x-y', 'AdjT_x-y', 'SRS_x-y']",
#  "['luck_x-y', 'SOS_x-y', 'PT_Ratio_x-y']",
#  "['luck_x-y', 'SRS_x-y', 'True_S_x-y']",
#  "['AdjO_x-y', 'AdjD_x-y', 'L_x-y']",
#  "['AdjT_x-y', 'SRS_x-y', 'seed_x-y']",
#  "['W_L_ratio_x-y', 'SOS_x-y', 'PT_Ratio_x-y']",
#  "['AdjD_x-y', 'luck_x-y', 'W_L_ratio_x-y']",
#  "['luck_x-y', 'W_L_ratio_x-y', 'SRS_x-y']",
#  "['TM_pt_x-y', 'True_S_x-y']",
#  "['luck_x-y', 'SRS_x-y', 'SOS_x-y']",
#  "['luck_x-y', 'TM_pt_x-y']",
#  "['AdjEM_x-y', 'W_L_ratio_x-y', 'SOS_x-y']",
#  "['AdjD_x-y', 'luck_x-y', 'True_S_x-y']",
#  "['AdjD_x-y', 'luck_x-y', 'SRS_x-y']",
#  "['AdjT_x-y', 'L_x-y', 'seed_x-y']",
#  "['AdjD_x-y', 'luck_x-y', 'PT_Ratio_x-y']",
#  "['TM_pt_x-y', 'PT_Ratio_x-y']",
#  "['W_L_ratio_x-y', 'SRS_x-y', 'True_S_x-y']",
#  "['AdjEM_x-y', 'AdjT_x-y', 'PT_Ratio_x-y']",
#  "['OPPO_pt_x-y', 'True_S_x-y']",
#  "['AdjD_x-y', 'W_L_ratio_x-y', 'PT_Ratio_x-y']",
#  "['luck_x-y', 'SRS_x-y', 'PT_Ratio_x-y']",
#  "['AdjEM_x-y', 'W_x-y', 'SRS_x-y']",
#  "['AdjEM_x-y', 'L_x-y', 'True_S_x-y']",
#  "['AdjEM_x-y', 'AdjT_x-y', 'luck_x-y']",
#  "['SRS_x-y', 'PT_Ratio_x-y']",
#  "['AdjEM_x-y', 'AdjT_x-y', 'L_x-y']",
#  "['AdjD_x-y', 'L_x-y', 'W_L_ratio_x-y']",
#  "['SRS_x-y', 'SOS_x-y', 'PT_Ratio_x-y']",
#  "['W_L_ratio_x-y', 'SOS_x-y', 'True_S_x-y']",
#  "['AdjO_x-y', 'L_x-y', 'SRS_x-y']",
#  "['AdjEM_x-y', 'SOS_x-y', 'PT_Ratio_x-y']",
#  "['luck_x-y', 'PT_Ratio_x-y', 'seed_x-y']",
#  "['AdjEM_x-y', 'AdjT_x-y', 'W_L_ratio_x-y']",
#  "['SRS_x-y', 'SOS_x-y', 'True_S_x-y']",
#  "['SOS_x-y', 'PT_Ratio_x-y', 'True_S_x-y']",
#  "['SRS_x-y', 'SOS_x-y']",
#  "['AdjEM_x-y', 'luck_x-y', 'L_x-y']",
#  "['AdjEM_x-y', 'SOS_x-y', 'True_S_x-y']",
#  "['luck_x-y', 'OPPO_pt_x-y']",
#  "['AdjEM_x-y', 'L_x-y', 'W_L_ratio_x-y']",
#  "['SRS_x-y', 'True_S_x-y']",
#  "['AdjD_x-y', 'SRS_x-y', 'PT_Ratio_x-y']",
#  "['W_L_ratio_x-y', 'TM_pt_x-y']",
#  "['AdjEM_x-y', 'luck_x-y', 'SRS_x-y']",
#  "['luck_x-y', 'SRS_x-y']",
#  "['W_L_ratio_x-y', 'SRS_x-y']",
#  "['AdjEM_x-y', 'L_x-y', 'PT_Ratio_x-y']",
#  "['W_L_ratio_x-y', 'OPPO_pt_x-y']",
#  "['luck_x-y', 'True_S_x-y', 'seed_x-y']",
#  "['OPPO_pt_x-y', 'PT_Ratio_x-y']",
#  "['AdjT_x-y', 'SOS_x-y', 'seed_x-y']",
#  "['W_x-y', 'SRS_x-y']",
#  "['SOS_x-y', 'PT_Ratio_x-y']",
#  "['AdjEM_x-y', 'L_x-y', 'seed_x-y']",
#  "['PT_Ratio_x-y', 'True_S_x-y', 'seed_x-y']",
#  "['AdjEM_x-y', 'W_L_ratio_x-y', 'SRS_x-y']",
#  "['W_L_ratio_x-y', 'True_S_x-y', 'seed_x-y']",
#  "['AdjEM_x-y', 'AdjT_x-y', 'seed_x-y']",
#  "['AdjT_x-y', 'SRS_x-y', 'SOS_x-y']",
#  "['W_L_ratio_x-y', 'seed_x-y']",
#  "['AdjEM_x-y', 'SRS_x-y', 'True_S_x-y']",
#  "['AdjD_x-y', 'AdjT_x-y', 'seed_x-y']",
#  "['W_L_ratio_x-y', 'PT_Ratio_x-y', 'seed_x-y']",
#  "['luck_x-y', 'SOS_x-y']",
#  "['W_L_ratio_x-y', 'SOS_x-y']",
#  "['SOS_x-y', 'True_S_x-y']",
#  "['AdjO_x-y', 'SRS_x-y', 'seed_x-y']",
#  "['AdjEM_x-y', 'SRS_x-y', 'PT_Ratio_x-y']",
#  "['AdjD_x-y', 'seed_x-y']",
#  "['TM_pt_x-y']",
#  "['AdjO_x-y', 'SRS_x-y', 'SOS_x-y']",
#  "['AdjEM_x-y', 'AdjT_x-y', 'SOS_x-y']",
#  "['SRS_x-y']",
#  "['AdjD_x-y', 'luck_x-y', 'seed_x-y']",
#  "['AdjO_x-y', 'luck_x-y', 'SRS_x-y']",
#  "['AdjD_x-y', 'True_S_x-y', 'seed_x-y']",
#  "['AdjO_x-y', 'SRS_x-y', 'True_S_x-y']",
#  "['AdjO_x-y', 'SRS_x-y', 'PT_Ratio_x-y']",
#  "['AdjD_x-y', 'PT_Ratio_x-y', 'seed_x-y']",
#  "['luck_x-y', 'W_L_ratio_x-y', 'seed_x-y']",
#  "['AdjO_x-y', 'W_L_ratio_x-y']",
#  "['AdjD_x-y', 'W_L_ratio_x-y', 'seed_x-y']",
#  "['AdjT_x-y', 'W_L_ratio_x-y', 'SOS_x-y']",
#  "['AdjO_x-y', 'AdjT_x-y', 'W_L_ratio_x-y']",
#  "['True_S_x-y', 'seed_x-y']",
#  "['AdjO_x-y', 'AdjT_x-y', 'seed_x-y']",
#  "['AdjO_x-y', 'W_L_ratio_x-y', 'SOS_x-y']",
#  "['AdjEM_x-y', 'L_x-y']",
#  "['PT_Ratio_x-y', 'seed_x-y']",
#  "['AdjEM_x-y', 'SOS_x-y']",
#  "['AdjT_x-y', 'SOS_x-y', 'True_S_x-y']",
#  "['W_L_ratio_x-y', 'TM_pt_x-y', 'True_S_x-y']",
#  "['AdjO_x-y', 'luck_x-y', 'W_L_ratio_x-y']",
#  "['AdjT_x-y', 'seed_x-y']",
#  "['AdjO_x-y', 'luck_x-y', 'PT_Ratio_x-y']",
#  "['AdjO_x-y', 'True_S_x-y']",
#  "['AdjO_x-y', 'SOS_x-y', 'PT_Ratio_x-y']",
#  "['AdjO_x-y', 'W_L_ratio_x-y', 'True_S_x-y']",
#  "['OPPO_pt_x-y']",
#  "['luck_x-y', 'W_L_ratio_x-y', 'TM_pt_x-y']",
#  "['AdjO_x-y', 'luck_x-y', 'True_S_x-y']",
#  "['AdjO_x-y', 'luck_x-y', 'SOS_x-y']",
#  "['TM_pt_x-y', 'PT_Ratio_x-y', 'True_S_x-y']",
#  "['AdjT_x-y', 'SOS_x-y', 'PT_Ratio_x-y']",
#  "['seed_x-y']",
#  "['AdjO_x-y', 'luck_x-y']",
#  "['AdjO_x-y', 'AdjT_x-y', 'PT_Ratio_x-y']",
#  "['AdjO_x-y', 'PT_Ratio_x-y', 'True_S_x-y']",
#  "['luck_x-y', 'seed_x-y']",
#  "['AdjEM_x-y', 'AdjT_x-y', 'SRS_x-y']",
#  "['AdjO_x-y', 'W_L_ratio_x-y', 'PT_Ratio_x-y']",
#  "['AdjO_x-y', 'AdjT_x-y', 'True_S_x-y']",
#  "['luck_x-y', 'TM_pt_x-y', 'True_S_x-y']",
#  "['SOS_x-y']",
#  "['AdjO_x-y']",
#  "['AdjO_x-y', 'AdjT_x-y']",
#  "['W_L_ratio_x-y', 'TM_pt_x-y', 'PT_Ratio_x-y']",
#  "['AdjO_x-y', 'PT_Ratio_x-y']",
#  "['AdjT_x-y', 'luck_x-y', 'SOS_x-y']",
#  "['AdjO_x-y', 'W_L_ratio_x-y', 'SRS_x-y']",
#  "['luck_x-y', 'TM_pt_x-y', 'PT_Ratio_x-y']",
#  "['AdjEM_x-y', 'SRS_x-y']",
#  "['AdjO_x-y', 'SOS_x-y']",
#  "['AdjO_x-y', 'SOS_x-y', 'True_S_x-y']",
#  "['AdjO_x-y', 'SRS_x-y']",
#  "['AdjO_x-y', 'AdjT_x-y', 'luck_x-y']",
#  "['AdjT_x-y', 'True_S_x-y', 'seed_x-y']",
#  "['AdjT_x-y', 'SOS_x-y']",
#  "['AdjT_x-y', 'luck_x-y', 'seed_x-y']",
#  "['AdjT_x-y', 'PT_Ratio_x-y', 'seed_x-y']",
#  "['OPPO_pt_x-y', 'PT_Ratio_x-y', 'True_S_x-y']",
#  "['AdjO_x-y', 'seed_x-y']",
#  "['AdjEM_x-y', 'L_x-y', 'SRS_x-y']",
#  "['AdjO_x-y', 'luck_x-y', 'seed_x-y']",
#  "['W_L_ratio_x-y', 'OPPO_pt_x-y', 'PT_Ratio_x-y']",
#  "['luck_x-y', 'OPPO_pt_x-y', 'PT_Ratio_x-y']",
#  "['L_x-y', 'SRS_x-y', 'PT_Ratio_x-y']",
#  "['AdjT_x-y', 'W_L_ratio_x-y', 'seed_x-y']",
#  "['AdjO_x-y', 'PT_Ratio_x-y', 'seed_x-y']",
#  "['luck_x-y', 'W_L_ratio_x-y', 'OPPO_pt_x-y']",
#  "['W_L_ratio_x-y', 'OPPO_pt_x-y', 'True_S_x-y']",
#  "['AdjT_x-y', 'SRS_x-y', 'True_S_x-y']",
#  "['L_x-y', 'W_L_ratio_x-y', 'SRS_x-y']",
#  "['AdjT_x-y', 'SRS_x-y']",
#  "['luck_x-y', 'L_x-y', 'SRS_x-y']",
#  "['luck_x-y', 'OPPO_pt_x-y', 'True_S_x-y']",
#  "['L_x-y', 'SRS_x-y', 'True_S_x-y']",
#  "['AdjO_x-y', 'W_L_ratio_x-y', 'seed_x-y']",
#  "['AdjT_x-y', 'SRS_x-y', 'PT_Ratio_x-y']",
#  "['AdjO_x-y', 'True_S_x-y', 'seed_x-y']",
#  "['AdjT_x-y', 'W_L_ratio_x-y', 'SRS_x-y']",
#  "['AdjT_x-y', 'luck_x-y', 'SRS_x-y']",
#  "['L_x-y', 'SRS_x-y']",
#  "['luck_x-y', 'L_x-y', 'seed_x-y']",
#  "['L_x-y', 'W_L_ratio_x-y', 'seed_x-y']",
#  "['L_x-y', 'True_S_x-y', 'seed_x-y']",
#  "['L_x-y', 'PT_Ratio_x-y', 'seed_x-y']",
#  "['L_x-y', 'seed_x-y']"]

# %%
X = np.array(d['master'][['AdjT_x-y', 'W_x-y', 'PT_Ratio_x-y']])  # 0.79051754386
y = np.array(d['master']['result'])

r_squared_lst = []
for i in range(100):
    X_train, X_test, y_train, y_test = cross_validation.train_test_split(X, y, test_size=0.15)

    clf = svm.SVC()
    clf.fit(X_train, y_train)
        
    cv = KFold(X_train.shape[0], 10, shuffle = True)
    r_squared = cross_val_score(clf, X_train, y_train, cv = cv)
    r_squared = np.mean(r_squared)
    r_squared_lst.append(r_squared)
print ("Average confidence w/ 100 repetitions for ", feature, "w/ 5-fold CV :", sum(r_squared_lst)/len(r_squared_lst))
feature_r_squared[str(feature)] = sum(r_squared_lst)/len(r_squared_lst)
# Out:
# Average confidence w/ 100 repetitions for  ['AdjEM_x-y'] w/ 5-fold CV : 0.791102339181

# %%
example_measures = np.array([[4,2,1,1,1,2,3,2,1]])

# %%
example_measures
# Out:
# array([[4, 2, 1, 1, 1, 2, 3, 2, 1]])

# %%
example_measures = example_measures.reshape(len(example_measures), -1)
